# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Sport-University/blob/main/kata1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # karate

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_1= pd.read_excel('https://github.com/vn322/Sport-University/raw/main/combat/kata0.xlsx')
df_1
# Out:
#       2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# 0                  53                53              21               15
# 1                  57                61              21               15
# 2                  59                61              22               13
# 3                  59                61              22               13
# 4                  59                62              21               13
# ...               ...               ...             ...              ...
# 1838               15                 2              36               51
# 1839               15                 2              36               50
# 1840               10                 3              37               50
# 1841                9                 3              37               50
# 1842               10                 3              37               50
#
#       2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# ...

# %%
df_1.describe()
# Out:
#        2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# count      1843.000000       1843.000000     1843.000000      1843.000000
# mean         80.278893         60.050461       44.705914        39.851872
# std          53.371888         43.835285       31.817840        30.573016
# min           1.000000          1.000000        0.000000         0.000000
# 25%          34.000000         23.000000       21.000000        15.000000
# 50%          71.000000         57.000000       42.000000        36.000000
# 75%         124.500000         86.000000       61.000000        57.000000
# max         180.000000        180.000000      177.000000       179.000000
#
#        2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# count     1843.000000      1843.000000      1843.000000       1843.000000
# mean        39.956593        34.692892        37.705372         31.693435
# std         27.024484        24.441228        30.537290         27.034740
# ...

# %%
df_3=df_1[['3D_Левый локоть', '3D_Правый локоть', '3D_Левое плечо',
       '3D_Правое плечо', '3D_Левое бедро', '3D_Правое бедро',
       '3D_Левое колено', '3D_Правое колено', 'X-angle']]

# %%
df_3.describe()
# Out:
#        3D_Левый локоть  3D_Правый локоть  3D_Левое плечо  3D_Правое плечо  \
# count      1843.000000       1843.000000     1843.000000      1843.000000
# mean         45.578405         48.590884       88.226804        83.920781
# std          29.614400         31.289718       31.868803        33.603119
# min           1.000000          0.000000        5.000000         4.000000
# 25%          24.000000         24.000000       63.000000        59.000000
# 50%          35.000000         40.000000       91.000000        84.000000
# 75%          63.000000         67.000000      113.500000       113.000000
# max         154.000000        150.000000      157.000000       149.000000
#
#        3D_Левое бедро  3D_Правое бедро  3D_Левое колено  3D_Правое колено  \
# count     1843.000000      1843.000000      1843.000000       1843.000000
# mean        84.539338        78.343462       101.793272         85.478568
# std         30.631375        34.554019        37.804445         43.924609
# ...

# %% [markdown]
# ## корреляция

# %%
df_3.corr()
# Out:
#                   3D_Левый локоть  3D_Правый локоть  3D_Левое плечо  \
# 3D_Левый локоть          1.000000          0.228339       -0.452033
# 3D_Правый локоть         0.228339          1.000000       -0.031925
# 3D_Левое плечо          -0.452033         -0.031925        1.000000
# 3D_Правое плечо         -0.103972         -0.528679        0.308587
# 3D_Левое бедро          -0.042617          0.114525        0.275036
# 3D_Правое бедро         -0.024251         -0.072146        0.080258
# 3D_Левое колено         -0.050835          0.071506        0.089351
# 3D_Правое колено        -0.013304          0.068937        0.100631
# X-angle                 -0.062160         -0.124155        0.000284
#
#                   3D_Правое плечо  3D_Левое бедро  3D_Правое бедро  \
# 3D_Левый локоть         -0.103972       -0.042617        -0.024251
# 3D_Правый локоть        -0.528679        0.114525        -0.072146
# 3D_Левое плечо           0.308587        0.275036         0.080258
# ...

# %%
plt.figure(figsize=(16, 6))

# %%
sns.heatmap(df_3.corr(), annot=True, fmt=".1f",cmap="Pastel1" )
# Out:
# <Axes: >

# %%
df_3.corr()[['X-angle']].sort_values(by='X-angle', ascending=False)
# Out:
#                    X-angle
# X-angle           1.000000
# 3D_Левое бедро    0.050851
# 3D_Правое плечо   0.048676
# 3D_Левое плечо    0.000284
# 3D_Правое бедро  -0.008258
# 3D_Левый локоть  -0.062160
# 3D_Правый локоть -0.124155
# 3D_Правое колено -0.133350
# 3D_Левое колено  -0.134736

# %%
c = df_3.corr()
np.fill_diagonal(c.values, 0)
s = c.unstack()
s.sort_values(kind="quicksort")
# Out:
# 3D_Правое плечо   3D_Правый локоть   -0.528679
# 3D_Правый локоть  3D_Правое плечо    -0.528679
# 3D_Левый локоть   3D_Левое плечо     -0.452033
# 3D_Левое плечо    3D_Левый локоть    -0.452033
# X-angle           3D_Левое колено    -0.134736
#                                         ...
# 3D_Левое колено   3D_Правое колено    0.533132
#                   3D_Левое бедро      0.621491
# 3D_Левое бедро    3D_Левое колено     0.621491
# 3D_Правое бедро   3D_Правое колено    0.621600
# 3D_Правое колено  3D_Правое бедро     0.621600
# Length: 81, dtype: float64

# %%
# Create correlation matrix
corr_mat = df_3.corr(method='pearson')
np.fill_diagonal(corr_mat.values, 0)
# Convert correlation matrix to 1-D Series and sort
sorted_mat = corr_mat.unstack().sort_values(ascending=False)

print(sorted_mat)
s =sorted_mat.abs()
s[s>0.5]
# Out:
# 3D_Правое колено  3D_Правое бедро     0.621600
# 3D_Правое бедро   3D_Правое колено    0.621600
# 3D_Левое бедро    3D_Левое колено     0.621491
# 3D_Левое колено   3D_Левое бедро      0.621491
#                   3D_Правое колено    0.533132
#                                         ...
# X-angle           3D_Левое колено    -0.134736
# 3D_Левое плечо    3D_Левый локоть    -0.452033
# 3D_Левый локоть   3D_Левое плечо     -0.452033
# 3D_Правое плечо   3D_Правый локоть   -0.528679
# 3D_Правый локоть  3D_Правое плечо    -0.528679
# Length: 81, dtype: float64
# 3D_Правое колено  3D_Правое бедро     0.621600
# 3D_Правое бедро   3D_Правое колено    0.621600
# 3D_Левое бедро    3D_Левое колено     0.621491
# 3D_Левое колено   3D_Левое бедро      0.621491
#                   3D_Правое колено    0.533132
# 3D_Правое колено  3D_Левое колено     0.533132
# 3D_Правое плечо   3D_Правый локоть    0.528679
# 3D_Правый локоть  3D_Правое плечо     0.528679
# dtype: float64

# %%
# Create correlation matrix
corr_mat = df_3.corr(method='pearson')

# Retain upper triangular values of correlation matrix and
# make Lower triangular values Null
upper_corr_mat = corr_mat.where(
    np.triu(np.ones(corr_mat.shape), k=1).astype(bool))

# Convert to 1-D series and drop Null values
unique_corr_pairs = upper_corr_mat.unstack().dropna()

# Sort correlation pairs
sorted_mat = unique_corr_pairs.sort_values()
print(sorted_mat.sort_values(ascending=False))
# Out:
# 3D_Правое колено  3D_Правое бедро     0.621600
# 3D_Левое колено   3D_Левое бедро      0.621491
# 3D_Правое колено  3D_Левое колено     0.533132
# 3D_Правое плечо   3D_Левое плечо      0.308587
# 3D_Правое бедро   3D_Левое бедро      0.291584
# 3D_Левое бедро    3D_Правое плечо     0.275779
#                   3D_Левое плечо      0.275036
# 3D_Правое бедро   3D_Правое плечо     0.229028
# 3D_Правый локоть  3D_Левый локоть     0.228339
# 3D_Правое колено  3D_Левое бедро      0.223987
# 3D_Левое колено   3D_Правое бедро     0.181978
# 3D_Левое бедро    3D_Правый локоть    0.114525
# 3D_Правое колено  3D_Левое плечо      0.100631
# 3D_Левое колено   3D_Правое плечо     0.099598
#                   3D_Левое плечо      0.089351
# 3D_Правое бедро   3D_Левое плечо      0.080258
# 3D_Левое колено   3D_Правый локоть    0.071506
# 3D_Правое колено  3D_Правый локоть    0.068937
# X-angle           3D_Левое бедро      0.050851
#                   3D_Правое плечо     0.048676
# ...

# %%
df_should = df_3[['3D_Левое плечо','3D_Правое плечо','X-angle']]
df_should
# Out:
#       3D_Левое плечо  3D_Правое плечо    X-angle
# 0                 74               90  20.305396
# 1                 58               55  20.668897
# 2                 83               64  25.519238
# 3                 70               58  27.311958
# 4                 81               67  26.468337
# ...              ...              ...        ...
# 1838             103               98  12.154129
# 1839             103               99  11.871689
# 1840             103               99  11.454018
# 1841             104              102  11.349315
# 1842             104              102  12.551865
#
# [1843 rows x 3 columns]

# %%
df_should.corr()
# Out:
#                  3D_Левое плечо  3D_Правое плечо   X-angle
# 3D_Левое плечо         1.000000         0.308587  0.000284
# 3D_Правое плечо        0.308587         1.000000  0.048676
# X-angle                0.000284         0.048676  1.000000

# %%
df_knee = df_3[['3D_Левое колено', '3D_Правое колено','X-angle']]
df_knee
# Out:
#       3D_Левое колено  3D_Правое колено    X-angle
# 0                  92                66  20.305396
# 1                  84                54  20.668897
# 2                  87                57  25.519238
# 3                  88                58  27.311958
# 4                  93                60  26.468337
# ...               ...               ...        ...
# 1838              115                97  12.154129
# 1839              114                96  11.871689
# 1840              114                96  11.454018
# 1841              116                96  11.349315
# 1842              116                96  12.551865
#
# [1843 rows x 3 columns]

# %%
df_knee.corr()
# Out:
#                   3D_Левое колено  3D_Правое колено   X-angle
# 3D_Левое колено          1.000000          0.533132 -0.134736
# 3D_Правое колено         0.533132          1.000000 -0.133350
# X-angle                 -0.134736         -0.133350  1.000000

# %% [markdown]
# ## визуализация

# %%
df_should.plot(figsize=(18,7))
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_should, x="3D_Правое плечо", y="3D_Левое плечо")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='3D_Левое плечо'>

# %%
sns.lineplot(data=df_should, x="3D_Правое плечо", y="3D_Левое плечо")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='3D_Левое плечо'>

# %%
sns.lineplot(data=df_should, x="3D_Правое плечо", y="X-angle")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='X-angle'>

# %%
plt.subplot(1, 2, 1)
sns.countplot(x='3D_Правое плечо', data=df_should)
plt.subplot(1, 2, 2)
sns.countplot(x='3D_Левое плечо', data=df_should)
# Out:
# <Axes: xlabel='3D_Левое плечо', ylabel='count'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df_3['X-angle']
y = df_3['3D_Правое плечо']
z = df_3['3D_Левое плечо']

ax.set_xlabel("X-angle")
ax.set_ylabel('3D_Правое плечо')
ax.set_zlabel('3D_Левое плечо')

ax.scatter(x, y, z)

plt.show()

# %%
#sns.pairplot(df_3, hue="X-angle")

# %% [markdown]
# # taekwon

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_4= pd.read_excel('/content/video-03-10-24-10-32.xlsx')
df_4
# Out:
#       2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# 0                  57                47              12               14
# 1                  55                45              14               13
# 2                  54                44              14               13
# 3                  52                43              15               13
# 4                  52                42              15               13
# ...               ...               ...             ...              ...
# 1342               23                24               9                8
# 1343               23                25               9                8
# 1344               23                25               9                8
# 1345               23                25               9                8
# 1346               23                24              10                8
#
#       2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# ...

# %%
df_4.describe()
# Out:
#        2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# count      1347.000000       1347.000000     1347.000000      1347.000000
# mean         53.619896         64.107647       18.106904        16.796585
# std          49.010244         52.730633       17.816395        17.122239
# min           1.000000          1.000000        0.000000         0.000000
# 25%          17.000000         28.000000        9.000000         7.000000
# 50%          39.000000         39.000000       13.000000        12.000000
# 75%          71.000000        108.000000       20.000000        19.000000
# max         180.000000        179.000000       96.000000        85.000000
#
#        2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# count     1347.000000      1347.000000      1347.000000       1347.000000
# mean        13.071269        12.668894         9.057164          9.826281
# std          9.071008         9.767214         9.233660         10.704159
# ...

# %%
df_5=df_4[['3D_Левый локоть', '3D_Правый локоть', '3D_Левое плечо',
       '3D_Правое плечо', '3D_Левое бедро', '3D_Правое бедро',
       '3D_Левое колено', '3D_Правое колено', 'X-angle']]

# %%
df_5.describe()
# Out:
#        3D_Левый локоть  3D_Правый локоть  3D_Левое плечо  3D_Правое плечо  \
# count      1347.000000       1347.000000     1347.000000      1347.000000
# mean         52.172977         51.307350       47.344469        50.694878
# std          22.896153         23.385502       25.273337        23.673918
# min           3.000000          4.000000        3.000000         5.000000
# 25%          36.000000         35.000000       26.000000        33.000000
# 50%          52.000000         50.000000       44.000000        46.000000
# 75%          63.000000         63.000000       65.000000        68.000000
# max         149.000000        145.000000      117.000000       112.000000
#
#        3D_Левое бедро  3D_Правое бедро  3D_Левое колено  3D_Правое колено  \
# count     1347.000000      1347.000000      1347.000000       1347.000000
# mean        33.160356        32.927246        40.582777         40.527097
# std         21.354528        18.798353        23.483349         20.803113
# ...

# %% [markdown]
# ## корреляция

# %%
df_5.corr()
# Out:
#                   3D_Левый локоть  3D_Правый локоть  3D_Левое плечо  \
# 3D_Левый локоть          1.000000          0.101753       -0.237543
# 3D_Правый локоть         0.101753          1.000000        0.148256
# 3D_Левое плечо          -0.237543          0.148256        1.000000
# 3D_Правое плечо          0.026304         -0.260822        0.076854
# 3D_Левое бедро          -0.253597          0.139496        0.416263
# 3D_Правое бедро         -0.003307         -0.202785       -0.133363
# 3D_Левое колено         -0.131887         -0.017648        0.034817
# 3D_Правое колено        -0.014058         -0.023384       -0.081719
# X-angle                 -0.143380         -0.195432       -0.024569
#
#                   3D_Правое плечо  3D_Левое бедро  3D_Правое бедро  \
# 3D_Левый локоть          0.026304       -0.253597        -0.003307
# 3D_Правый локоть        -0.260822        0.139496        -0.202785
# 3D_Левое плечо           0.076854        0.416263        -0.133363
# ...

# %%
plt.figure(figsize=(16, 6))

# %%
sns.heatmap(df_5.corr(), annot=True, fmt=".1f",cmap="Pastel1" )
# Out:
# <Axes: >

# %%
df_5.corr()[['X-angle']].sort_values(by='X-angle', ascending=False)
# Out:
#                    X-angle
# X-angle           1.000000
# 3D_Левое колено   0.122736
# 3D_Правое колено  0.047458
# 3D_Правое плечо   0.028740
# 3D_Левое бедро    0.010596
# 3D_Правое бедро  -0.014590
# 3D_Левое плечо   -0.024569
# 3D_Левый локоть  -0.143380
# 3D_Правый локоть -0.195432

# %%
c = df_5.corr().abs()
np.fill_diagonal(c.values, 0)
s = c.unstack()
s.sort_values(kind="quicksort")
# Out:
# 3D_Левый локоть   3D_Левый локоть     0.000000
# 3D_Правое колено  3D_Правое колено    0.000000
# 3D_Левое колено   3D_Левое колено     0.000000
# 3D_Правое бедро   3D_Правое бедро     0.000000
# 3D_Правое плечо   3D_Правое плечо     0.000000
#                                         ...
# 3D_Левое колено   3D_Левое бедро      0.439996
# 3D_Правое колено  3D_Правое бедро     0.491070
# 3D_Правое бедро   3D_Правое колено    0.491070
# 3D_Правое колено  3D_Левое колено     0.678165
# 3D_Левое колено   3D_Правое колено    0.678165
# Length: 81, dtype: float64

# %%
# Create correlation matrix
corr_mat = df_5.corr(method='pearson')
np.fill_diagonal(corr_mat.values, 0)
# Convert correlation matrix to 1-D Series and sort
sorted_mat = corr_mat.unstack().sort_values(ascending=False)

print(sorted_mat)
s =sorted_mat.abs()
s[s>0.5]
# Out:
# 3D_Левое колено   3D_Правое колено    0.678165
# 3D_Правое колено  3D_Левое колено     0.678165
# 3D_Правое бедро   3D_Правое колено    0.491070
# 3D_Правое колено  3D_Правое бедро     0.491070
# 3D_Левое колено   3D_Левое бедро      0.439996
#                                         ...
# 3D_Левый локоть   3D_Левое плечо     -0.237543
# 3D_Левое бедро    3D_Левый локоть    -0.253597
# 3D_Левый локоть   3D_Левое бедро     -0.253597
# 3D_Правое плечо   3D_Правый локоть   -0.260822
# 3D_Правый локоть  3D_Правое плечо    -0.260822
# Length: 81, dtype: float64
# 3D_Левое колено   3D_Правое колено    0.678165
# 3D_Правое колено  3D_Левое колено     0.678165
# dtype: float64

# %%
# Create correlation matrix
corr_mat = df_5.corr(method='pearson')

# Retain upper triangular values of correlation matrix and
# make Lower triangular values Null
upper_corr_mat = corr_mat.where(
    np.triu(np.ones(corr_mat.shape), k=1).astype(bool))

# Convert to 1-D series and drop Null values
unique_corr_pairs = upper_corr_mat.unstack().dropna()

# Sort correlation pairs
sorted_mat = unique_corr_pairs.sort_values()
print(sorted_mat.sort_values(ascending=False))
# Out:
# 3D_Правое колено  3D_Левое колено     0.678165
#                   3D_Правое бедро     0.491070
# 3D_Левое колено   3D_Левое бедро      0.439996
# 3D_Левое бедро    3D_Левое плечо      0.416263
# 3D_Правое бедро   3D_Правое плечо     0.317463
#                   3D_Левое бедро      0.249585
# 3D_Правое колено  3D_Левое бедро      0.153069
# 3D_Левое плечо    3D_Правый локоть    0.148256
# 3D_Правое колено  3D_Правое плечо     0.142004
# 3D_Левое бедро    3D_Правый локоть    0.139496
# 3D_Левое колено   3D_Правое бедро     0.135282
# X-angle           3D_Левое колено     0.122736
# 3D_Правый локоть  3D_Левый локоть     0.101753
# 3D_Правое плечо   3D_Левое плечо      0.076854
# X-angle           3D_Правое колено    0.047458
# 3D_Левое колено   3D_Левое плечо      0.034817
# X-angle           3D_Правое плечо     0.028740
# 3D_Правое плечо   3D_Левый локоть     0.026304
# X-angle           3D_Левое бедро      0.010596
# 3D_Правое бедро   3D_Левый локоть    -0.003307
# ...

# %%
df_should = df_5[['3D_Левое плечо','3D_Правое плечо','X-angle']]
df_should
# Out:
#       3D_Левое плечо  3D_Правое плечо    X-angle
# 0                 32               35   6.267082
# 1                 40               46   3.470574
# 2                 44               49   3.855303
# 3                 45               50   3.031278
# 4                 46               50   3.054586
# ...              ...              ...        ...
# 1342              23               21  13.236893
# 1343              22               20  13.429582
# 1344              22               20  13.134243
# 1345              22               20  13.416843
# 1346              22               20  12.979700
#
# [1347 rows x 3 columns]

# %%
df_should.corr()
# Out:
#                  3D_Левое плечо  3D_Правое плечо   X-angle
# 3D_Левое плечо         1.000000         0.076854 -0.024569
# 3D_Правое плечо        0.076854         1.000000  0.028740
# X-angle               -0.024569         0.028740  1.000000

# %%
df_knee = df_5[['3D_Левое колено', '3D_Правое колено','X-angle']]
df_knee
# Out:
#       3D_Левое колено  3D_Правое колено    X-angle
# 0                  34                38   6.267082
# 1                  34                38   3.470574
# 2                  34                37   3.855303
# 3                  33                36   3.031278
# 4                  34                36   3.054586
# ...               ...               ...        ...
# 1342               43                42  13.236893
# 1343               42                42  13.429582
# 1344               42                41  13.134243
# 1345               42                41  13.416843
# 1346               42                42  12.979700
#
# [1347 rows x 3 columns]

# %%
df_knee.corr()
# Out:
#                   3D_Левое колено  3D_Правое колено   X-angle
# 3D_Левое колено          1.000000          0.678165  0.122736
# 3D_Правое колено         0.678165          1.000000  0.047458
# X-angle                  0.122736          0.047458  1.000000

# %% [markdown]
# ## визуализация

# %%
df_should.plot(figsize=(18,7))
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_should, x="3D_Правое плечо", y="3D_Левое плечо")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='3D_Левое плечо'>

# %%
sns.lineplot(data=df_should, x="3D_Правое плечо", y="3D_Левое плечо")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='3D_Левое плечо'>

# %%
sns.lineplot(data=df_should, x="3D_Правое плечо", y="X-angle")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='X-angle'>

# %%
plt.subplot(1, 2, 1)
sns.countplot(x='3D_Правое плечо', data=df_should)
plt.subplot(1, 2, 2)
sns.countplot(x='3D_Левое плечо', data=df_should)
# Out:
# <Axes: xlabel='3D_Левое плечо', ylabel='count'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df_5['X-angle']
y = df_5['3D_Правое плечо']
z = df_5['3D_Левое плечо']

ax.set_xlabel("X-angle")
ax.set_ylabel('3D_Правое плечо')
ax.set_zlabel('3D_Левое плечо')

ax.scatter(x, y, z)

plt.show()

# %%
#sns.pairplot(df_3, hue="X-angle")

# %% [markdown]
# # Статистика

# %%
df_left_knee = pd.DataFrame([df_3['3D_Левое колено'], df_5['3D_Левое колено']]).T

# %%
df_left_knee.columns=['kar','tkw']

# %%
(df_3['3D_Левое колено'], df_5['3D_Левое колено'])
# Out:
# (0        92
#  1        84
#  2        87
#  3        88
#  4        93
#         ...
#  1838    115
#  1839    114
#  1840    114
#  1841    116
#  1842    116
#  Name: 3D_Левое колено, Length: 1843, dtype: int64,
#  0       34
#  1       34
#  2       34
#  3       33
#  4       34
#          ..
#  1342    43
#  1343    42
#  1344    42
#  1345    42
#  1346    42
#  Name: 3D_Левое колено, Length: 1347, dtype: int64)

# %%
# Mann-Whitney U test

from scipy.stats import mannwhitneyu

stat, p = mannwhitneyu(df_3['3D_Левое колено'], df_5['3D_Левое колено'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=2224106.000, p=0.000
# Different distribution (reject H0)

# %%
# Mann-Whitney U test

from scipy.stats import mannwhitneyu

stat, p = mannwhitneyu(df_3['3D_Правое колено'], df_5['3D_Правое колено'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=1966452.000, p=0.000
# Different distribution (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(df_3['3D_Левое колено'], df_5['3D_Левое колено'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=1463.382, p=0.000
# Different distributions (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(df_3['3D_Правое колено'], df_5['3D_Правое колено'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=796.708, p=0.000
# Different distributions (reject H0)

# %%
# Mann-Whitney U test

from scipy.stats import mannwhitneyu

stat, p = mannwhitneyu(df_3['X-angle'], df_5['X-angle'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=1686131.000, p=0.000
# Different distribution (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(df_3['X-angle'], df_5['X-angle'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=299.798, p=0.000
# Different distributions (reject H0)

# %%
x_ang = pd.DataFrame([df_3['X-angle'], df_5['X-angle']]).T

# %%
x_ang[:1200].corr()
# Out:
#           X-angle   X-angle
# X-angle  1.000000  0.020177
# X-angle  0.020177  1.000000

# %% [markdown]
# # Furie

# %%
df_3['3D_Левое колено'].shift(1) - df_3['3D_Левое колено']
# Out:
# 0       NaN
# 1       8.0
# 2      -3.0
# 3      -1.0
# 4      -5.0
#        ...
# 1838    0.0
# 1839    1.0
# 1840    0.0
# 1841   -2.0
# 1842    0.0
# Name: 3D_Левое колено, Length: 1843, dtype: float64

# %%
df_3['3D_Левое колено']
# Out:
# 0        92
# 1        84
# 2        87
# 3        88
# 4        93
#        ...
# 1838    115
# 1839    114
# 1840    114
# 1841    116
# 1842    116
# Name: 3D_Левое колено, Length: 1843, dtype: int64

# %%
(df_3['X-angle'].shift(1) - df_3['X-angle']).plot(kind='line')
# Out:
# <Axes: >

# %%
(df_5['X-angle'].shift(1) - df_5['X-angle']).plot(kind='line')
# Out:
# <Axes: >

# %%
x_vel = pd.DataFrame([df_3['X-angle'].shift(1) - df_3['X-angle'], df_5['X-angle'].shift(1) - df_5['X-angle']]).T

# %%
x_vel[:1200].corr()
# Out:
#           X-angle   X-angle
# X-angle  1.000000  0.009858
# X-angle  0.009858  1.000000

# %%
(df_3['3D_Левое колено'].shift(1) - df_3['3D_Левое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
(df_5['3D_Левое колено'].shift(1) - df_5['3D_Левое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt



# Создаем массив значений x от -10 до 10
#x = np.linspace(0, 1843, 1843)
x = range(1843)

# Вычисляем значения y для первой и второй функций
y1 = df_3['3D_Левое колено'].shift(1) - df_3['3D_Левое колено']
y2 = df_3['3D_Левое колено']

# Строим график двух функций
plt.plot(x, y1.abs(), label='der')
plt.plot(x, y2, label='raw')

# Добавляем заголовок и метки осей
plt.title('Графики ')
plt.xlabel('x')
plt.ylabel('y')

# Добавляем легенду
plt.legend()

# Показываем график
plt.show()

# %%
(df_3['3D_Левое колено'].shift(1) - df_3['3D_Левое колено']).plot()
# Out:
# <Axes: >

# %%
ser = pd.Series(df_3['3D_Левое колено'].shift(1) - df_3['3D_Левое колено'])

# %%
from scipy.fft import fft, fftfreq,ifft
fft(df_3['3D_Левое колено'])
# Out:
# array([187605.            -0.j        ,  -2480.37421801 -3869.76907856j,
#          9211.0104717 +20956.09513033j, ...,
#         -4888.88468824 -6064.89771797j,   9211.0104717 -20956.09513033j,
#         -2480.37421801 +3869.76907856j])

# %%
ifft(fft(df_3['3D_Левое колено']))
# Out:
# array([ 92.+1.39872439e-14j,  84.-3.29633228e-16j,  87.-8.72853366e-15j,
#        ..., 114.-1.90671541e-15j, 116.+3.47906536e-15j,
#        116.+1.65239238e-15j])

# %%
df_3['3D_Левое колено']
# Out:
# 0        92
# 1        84
# 2        87
# 3        88
# 4        93
#        ...
# 1838    115
# 1839    114
# 1840    114
# 1841    116
# 1842    116
# Name: 3D_Левое колено, Length: 1843, dtype: int64

# %%
fftfreq(1843,df_3['3D_Левое колено'])
# Out:
# 0       0.000000
# 1       0.000006
# 2       0.000012
# 3       0.000018
# 4       0.000023
#           ...
# 1838   -0.000024
# 1839   -0.000019
# 1840   -0.000014
# 1841   -0.000009
# 1842   -0.000005
# Name: 3D_Левое колено, Length: 1843, dtype: float64

# %%
fftfreq(1843,df_3['3D_Левое колено']).plot()
# Out:
# <Axes: >

# %%
fftfreq(1347,df_5['3D_Левое колено']).plot()
# Out:
# <Axes: >

# %%
(df_3['X-angle']).plot()
# Out:
# <Axes: >

# %%
fftfreq(1843,df_3['X-angle']).plot()
# Out:
# <Axes: >

# %%
(df_5['X-angle']).plot()
# Out:
# <Axes: >

# %%
fftfreq(1347,df_5['X-angle']).plot()
# Out:
# <Axes: >

# %%
fftfreq(8,np.array([-2, 8, 6, 4, 1, 8, 3, 5]))
# Out:
# array([-0.        ,  0.015625  ,  0.04166667,  0.09375   , -0.5       ,
#        -0.046875  , -0.08333333, -0.025     ])
