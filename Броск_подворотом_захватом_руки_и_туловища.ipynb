# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Sport-University/blob/main/%D0%91%D1%80%D0%BE%D1%81%D0%BA_%D0%BF%D0%BE%D0%B4%D0%B2%D0%BE%D1%80%D0%BE%D1%82%D0%BE%D0%BC_%D0%B7%D0%B0%D1%85%D0%B2%D0%B0%D1%82%D0%BE%D0%BC_%D1%80%D1%83%D0%BA%D0%B8_%D0%B8_%D1%82%D1%83%D0%BB%D0%BE%D0%B2%D0%B8%D1%89%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # data

# %%
wr = pd.read_excel('https://github.com/vn322/Sport-University/raw/refs/heads/main/combat/%D0%B2%D0%B1%20%D0%B1%D1%80%D0%BE%D1%81%D0%BE%D0%BA%20%D0%BF%D0%BE%D0%B4%D0%B2%D0%BE%D1%80%D0%BE%D1%82%D0%BE%D0%BC%20%D0%B7%D0%B0%D1%85%D0%B2%D0%B0%D1%82%D0%BE%D0%BC%20%D1%80%D1%83%D0%BA%D0%B8%20%D0%B8%20%D1%82%D1%83%D0%BB%D0%BE%D0%B2%D0%B8%D1%89%D0%B0.xlsx')
wr.head(3)
# Out:
#    2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# 0              120               137              13               39
# 1              121               168              14               36
# 2              121               176              16               25
#
#    2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# 0              12               76                4                 4
# 1              15               77                2                 5
# 2              17               78                1                 7
#
#    2D_Левый голеностоп  2D_Правый голеностоп  ...  3D_Левое бедро  \
# 0                   38                    66  ...              76
# 1                   39                    59  ...              84
# 2                   39                    58  ...              87
#
#    3D_Правое бедро  3D_Левое колено  3D_Правое колено  3D_Левый голеностоп  \
# ...

# %%
wrw = pd.read_excel('https://github.com/vn322/Sport-University/raw/refs/heads/main/combat/%D0%B2%D0%B1%20%D0%B6%20%D0%91%D1%80%D0%BE%D1%81%D0%BE%D0%BA%20%D0%BF%D0%BE%D0%B4%D0%B2%D0%BE%D1%80%D0%BE%D1%82%D0%BE%D0%BC%20%D0%B7%D0%B0%D1%85%D0%B2%D0%B0%D1%82%D0%BE%D0%BC%20%D1%80%D1%83%D0%BA%D0%B8%20%D0%B8%20%D1%82%D1%83%D0%BB%D0%BE%D0%B2%D0%B8%D1%89%D0%B0.xlsx')
wrw.head(3)
# Out:
#    2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# 0               13                31              76               47
# 1               20                26              80               51
# 2               18                23              81               51
#
#    2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# 0              28                7               52                33
# 1              31               15               54                36
# 2              32               13               54                32
#
#    2D_Левый голеностоп  2D_Правый голеностоп  ...  3D_Левое бедро  \
# 0                   26                    23  ...              18
# 1                   27                    23  ...              20
# 2                   27                    22  ...              27
#
#    3D_Правое бедро  3D_Левое колено  3D_Правое колено  3D_Левый голеностоп  \
# ...

# %%
gr = pd.read_excel('https://github.com/vn322/Sport-University/raw/refs/heads/main/combat/%D0%B3%D1%80%D0%B1%20%D0%91%D1%80%D0%BE%D1%81%D0%BA%20%D0%BF%D0%BE%D0%B4%D0%B2%D0%BE%D1%80%D0%BE%D1%82%D0%BE%D0%BC%20%D0%B7%D0%B0%D1%85%D0%B2%D0%B0%D1%82%D0%BE%D0%BC%20%D1%80%D1%83%D0%BA%D0%B8%20%D0%B8%20%D1%82%D1%83%D0%BB%D0%BE%D0%B2%D0%B8%D1%89%D0%B0.xlsx')
gr.head(3)
# Out:
#    2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# 0              150                63              50               59
# 1              149               154              50               35
# 2              149               155              53               22
#
#    2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# 0              28               22               14                13
# 1              24               17               12                 2
# 2              24               17               11                 1
#
#    2D_Левый голеностоп  2D_Правый голеностоп  ...  3D_Левое бедро  \
# 0                   21                    45  ...              28
# 1                   21                    50  ...              29
# 2                   21                    52  ...              33
#
#    3D_Правое бедро  3D_Левое колено  3D_Правое колено  3D_Левый голеностоп  \
# ...

# %%
wr1 = wr[['3D_Левое бедро', '3D_Правое бедро',
       '3D_Левое колено', '3D_Правое колено', 'X-angle']].iloc[5:62]
wr1.describe().round(2)
# Out:
#        3D_Левое бедро  3D_Правое бедро  3D_Левое колено  3D_Правое колено  \
# count           57.00            57.00            57.00             57.00
# mean            89.25           102.19           102.51            107.32
# std             31.04            41.27            25.45             24.02
# min             26.00            12.00            32.00             28.00
# 25%             66.00            60.00            94.00            102.00
# 50%             88.00           120.00           105.00            118.00
# 75%            107.00           135.00           113.00            123.00
# max            151.00           148.00           145.00            134.00
#
#        X-angle
# count    57.00
# mean     24.54
# std      28.04
# min       1.80
# 25%       7.88
# 50%      13.38
# 75%      28.04
# max     131.51

# %%
wrw1 = wrw[['3D_Левое бедро', '3D_Правое бедро',
       '3D_Левое колено', '3D_Правое колено', 'X-angle']].iloc[131:171]
wrw1.describe().round(2)
# Out:
#        3D_Левое бедро  3D_Правое бедро  3D_Левое колено  3D_Правое колено  \
# count           40.00            40.00            40.00             40.00
# mean            94.48            64.80            83.10             87.42
# std             36.06            26.19            57.09             42.61
# min             25.00            19.00             2.00             20.00
# 25%             65.00            44.75            21.25             50.50
# 50%             88.50            62.50           109.50             82.50
# 75%            129.00            86.75           137.50            125.25
# max            150.00           122.00           155.00            161.00
#
#        X-angle
# count    40.00
# mean     15.41
# std      18.75
# min       0.72
# 25%       4.70
# 50%       8.02
# 75%      17.30
# max      78.67

# %%
gr1 = gr[['3D_Левое бедро', '3D_Правое бедро',
       '3D_Левое колено', '3D_Правое колено', 'X-angle']].iloc[61:109]
gr1.describe().round(2)
# Out:
#        3D_Левое бедро  3D_Правое бедро  3D_Левое колено  3D_Правое колено  \
# count           48.00            48.00            48.00             48.00
# mean            69.17            63.25            93.77            101.17
# std             38.99            30.60            30.80             34.86
# min             17.00            14.00            15.00              8.00
# 25%             36.75            41.00            76.00             91.50
# 50%             67.50            55.50            97.50            115.00
# 75%             86.25            85.50           110.00            121.00
# max            143.00           128.00           149.00            143.00
#
#        X-angle
# count    48.00
# mean     18.96
# std      14.99
# min       1.89
# 25%       4.33
# 50%      17.34
# 75%      25.19
# max      61.70

# %% [markdown]
# # corr

# %%
wr1.corr()
# Out:
#                   3D_Левое бедро  3D_Правое бедро  3D_Левое колено  \
# 3D_Левое бедро          1.000000         0.652070         0.648445
# 3D_Правое бедро         0.652070         1.000000         0.302658
# 3D_Левое колено         0.648445         0.302658         1.000000
# 3D_Правое колено        0.240329         0.609362         0.580994
# X-angle                 0.011503        -0.283944         0.272175
#
#                   3D_Правое колено   X-angle
# 3D_Левое бедро            0.240329  0.011503
# 3D_Правое бедро           0.609362 -0.283944
# 3D_Левое колено           0.580994  0.272175
# 3D_Правое колено          1.000000 -0.020431
# X-angle                  -0.020431  1.000000

# %%
sns.heatmap(wr1.corr(), annot=True, fmt=".1f",cmap="Pastel1" )
# Out:
# <Axes: >

# %%
wrw1.corr()
# Out:
#                   3D_Левое бедро  3D_Правое бедро  3D_Левое колено  \
# 3D_Левое бедро          1.000000         0.184519         0.567426
# 3D_Правое бедро         0.184519         1.000000         0.080525
# 3D_Левое колено         0.567426         0.080525         1.000000
# 3D_Правое колено        0.220505         0.373158         0.768676
# X-angle                 0.246693         0.040578         0.531403
#
#                   3D_Правое колено   X-angle
# 3D_Левое бедро            0.220505  0.246693
# 3D_Правое бедро           0.373158  0.040578
# 3D_Левое колено           0.768676  0.531403
# 3D_Правое колено          1.000000  0.450021
# X-angle                   0.450021  1.000000

# %%
sns.heatmap(wrw1.corr(), annot=True, fmt=".1f",cmap="Pastel1" )
# Out:
# <Axes: >

# %%
gr1.corr()
# Out:
#                   3D_Левое бедро  3D_Правое бедро  3D_Левое колено  \
# 3D_Левое бедро          1.000000         0.792782         0.709192
# 3D_Правое бедро         0.792782         1.000000         0.576594
# 3D_Левое колено         0.709192         0.576594         1.000000
# 3D_Правое колено       -0.010619         0.274837         0.562793
# X-angle                 0.038572        -0.182408         0.078800
#
#                   3D_Правое колено   X-angle
# 3D_Левое бедро           -0.010619  0.038572
# 3D_Правое бедро           0.274837 -0.182408
# 3D_Левое колено           0.562793  0.078800
# 3D_Правое колено          1.000000  0.026985
# X-angle                   0.026985  1.000000

# %%
sns.heatmap(gr1.corr(), annot=True, fmt=".1f",cmap="Pastel1" )
# Out:
# <Axes: >

# %% [markdown]
# # dispers

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(wr1['3D_Правое колено'], wrw1['3D_Правое колено'],gr1['3D_Правое колено'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=2.350, p=0.309
# Same distributions (fail to reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(wr1['3D_Левое колено'], wrw1['3D_Левое колено'],gr1['3D_Левое колено'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=2.296, p=0.317
# Same distributions (fail to reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(wr1['3D_Правое бедро'], wrw1['3D_Правое бедро'],gr1['3D_Правое бедро'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=31.234, p=0.000
# Different distributions (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(wr1['3D_Левое бедро'], wrw1['3D_Левое бедро'],gr1['3D_Левое бедро'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=12.452, p=0.002
# Different distributions (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(wr1['X-angle'], wrw1['X-angle'],gr1['X-angle'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=5.987, p=0.050
# Same distributions (fail to reject H0)

# %% [markdown]
# # speed

# %%
wr1.columns
# Out:
# Index(['3D_Левое бедро', '3D_Правое бедро', '3D_Левое колено',
#        '3D_Правое колено', 'X-angle'],
#       dtype='object')

# %%
(wr1['3D_Левое колено'].shift(1) - wr1['3D_Левое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wr1['3D_Правое колено'].shift(1) - wr1['3D_Правое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wr1['3D_Левое бедро'].shift(1) - wr1['3D_Левое бедро']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wr1['3D_Правое бедро'].shift(1) - wr1['3D_Правое бедро']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wr1['X-angle'].shift(1) - wr1['X-angle']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wrw1['3D_Левое колено'].shift(1) - wrw1['3D_Левое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wrw1['3D_Правое колено'].shift(1) - wrw1['3D_Правое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wrw1['3D_Левое бедро'].shift(1) - wrw1['3D_Левое бедро']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wrw1['3D_Правое бедро'].shift(1) - wrw1['3D_Правое бедро']).plot(kind='line')
# Out:
# <Axes: >

# %%
(wrw1['X-angle'].shift(1) - wrw1['X-angle']).plot(kind='line')
# Out:
# <Axes: >

# %%
(gr1['3D_Левое колено'].shift(1) - gr1['3D_Левое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
(gr1['3D_Правое колено'].shift(1) - gr1['3D_Правое колено']).plot(kind='line')
# Out:
# <Axes: >

# %%
(gr1['3D_Левое бедро'].shift(1) - gr1['3D_Левое бедро']).plot(kind='line')
# Out:
# <Axes: >

# %%
(gr1['3D_Правое бедро'].shift(1) - gr1['3D_Правое бедро']).plot(kind='line')
# Out:
# <Axes: >

# %%
(gr1['X-angle'].shift(1) - gr1['X-angle']).plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# # furie

# %%
from scipy.fft import fft, fftfreq,ifft

# %%
fftfreq(57,wr1['X-angle']).plot()
# Out:
# <Axes: >

# %%
fftfreq(57,wr1['X-angle']).plot()
# Out:
# <Axes: >

# %%
fftfreq(40,wrw1['X-angle']).plot()
# Out:
# <Axes: >

# %%
fftfreq(48,gr1['X-angle']).plot()
# Out:
# <Axes: >

# %% [markdown]
# # regres

# %%
wr2 = wr1.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip", '3D_Левое колено':"leftknee", '3D_Правое колено':"rightknee",  'X-angle': "x_factor"}, errors="raise")
wr2.columns
# Out:
# Index(['lefthip', 'righthip', 'leftknee', 'rightknee', 'x_factor'], dtype='object')

# %%
import statsmodels.formula.api as smf

model = smf.ols('x_factor ~ lefthip + righthip + leftknee + rightknee', data=wr2)
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               x_factor   R-squared:                       0.225
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     3.778
# Date:                Tue, 19 Nov 2024   Prob (F-statistic):            0.00902
# Time:                        16:28:22   Log-Likelihood:                -263.13
# No. Observations:                  57   AIC:                             536.3
# Df Residuals:                      52   BIC:                             546.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5427     19.641      0.180      0.858     -35.870      42.956
# ...

# %%
wrw2 = wrw1.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip", '3D_Левое колено':"leftknee", '3D_Правое колено':"rightknee",  'X-angle': "x_factor"}, errors="raise")
wrw2.columns
# Out:
# Index(['lefthip', 'righthip', 'leftknee', 'rightknee', 'x_factor'], dtype='object')

# %%
import statsmodels.formula.api as smf

model = smf.ols('x_factor ~ lefthip + righthip + leftknee + rightknee', data=wrw2)
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               x_factor   R-squared:                       0.289
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     3.556
# Date:                Tue, 19 Nov 2024   Prob (F-statistic):             0.0155
# Time:                        16:29:01   Log-Likelihood:                -166.68
# No. Observations:                  40   AIC:                             343.4
# Df Residuals:                      35   BIC:                             351.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8502     10.273      0.180      0.858     -19.005      22.706
# ...

# %%
gr2 = gr1.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip", '3D_Левое колено':"leftknee", '3D_Правое колено':"rightknee",  'X-angle': "x_factor"}, errors="raise")
gr2.columns
# Out:
# Index(['lefthip', 'righthip', 'leftknee', 'rightknee', 'x_factor'], dtype='object')

# %%
import statsmodels.formula.api as smf

model = smf.ols('x_factor ~ lefthip + righthip + leftknee + rightknee', data=gr2)
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               x_factor   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     3.184
# Date:                Tue, 19 Nov 2024   Prob (F-statistic):             0.0224
# Time:                        16:29:25   Log-Likelihood:                -191.33
# No. Observations:                  48   AIC:                             392.7
# Df Residuals:                      43   BIC:                             402.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     15.2484      7.174      2.125      0.039       0.781      29.716
# ...
