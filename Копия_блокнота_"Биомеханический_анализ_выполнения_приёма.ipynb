# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Sport-University/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%91%D0%B8%D0%BE%D0%BC%D0%B5%D1%85%D0%B0%D0%BD%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B9_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B2%D1%8B%D0%BF%D0%BE%D0%BB%D0%BD%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Загрузка данных

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# # Лян Бао-бао

# %%
 df = pd.read_excel('/content/output (1).xlsx', index_col=None)
 df
# Out:
#     2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# 0                65                21              48               96
# 1                62                15              54              107
# 2                56                12              65              112
# 3                68                83              67               42
# 4                47               159              71               33
# ..              ...               ...             ...              ...
# 59              133               112              16               30
# 60              102                16              21                0
# 61              113               106              21               16
# 62               45                20              21               10
# 63               35                75              22                6
#
#     2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# 0               53               45               64                53
# 1               55               44               68                51
# 2               63               50               77                70
# 3               65               50               82                76
# 4               66               55               88                85
# ..             ...              ...              ...               ...
# 59              58               46              110                57
# 60              78               54              125                56
# 61              88               63              119                65
# 62             123               74              145                84
# 63             143              101              165               110
#
#     2D_Левый голеностоп  2D_Правый голеностоп  ...  3D_Левое бедро  \
# 0                    27                     9  ...              61
# 1                    28                    40  ...              64
# 2                    21                    29  ...              68
# 3                    17                    16  ...              76
# 4                    15                    16  ...              70
# ..                  ...                   ...  ...             ...
# 59                    9                    15  ...              33
# 60                   11                    28  ...              55
# 61                   15                    24  ...              36
# 62                   64                    29  ...              43
# 63                   31                    26  ...              80
#
#     3D_Правое бедро  3D_Левое колено  3D_Правое колено  3D_Левый голеностоп  \
# 0                75               63                40                   28
# 1                76               72                30                   27
# 2                74               81                41                   20
# 3                74               87                47                   20
# 4                81               89                54                   17
# ..              ...              ...               ...                  ...
# 59               23               57                30                   28
# 60               46               72                50                   24
# 61               25               48                30                   26
# 62               30               75                52                   63
# 63               58               85                60                   42
#
#     3D_Правый голеностоп  3D_Левое запястье  3D_Правое запястье    X-angle  \
# 0                     18                136                  54   1.177990
# 1                     42                 94                  34   0.822531
# 2                     35                 65                  69   0.948240
# 3                     42                 11                   9   1.503320
# 4                     29                  9                  14   2.589202
# ..                   ...                ...                 ...        ...
# 59                    24                 15                  17   7.385799
# 60                    25                 12                  44   5.124973
# 61                    25                 19                  13   2.551077
# 62                    30                 64                  31   7.447689
# 63                    25                 16                  14  10.947836
#
#             Time
# 0   1.696435e+09
# 1   1.696435e+09
# 2   1.696435e+09
# 3   1.696435e+09
# 4   1.696435e+09
# ..           ...
# 59  1.696435e+09
# 60  1.696435e+09
# 61  1.696435e+09
# 62  1.696435e+09
# 63  1.696435e+09
#
# [64 rows x 26 columns]

# %% [markdown]
# # Предварительное изучение

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   2D_Левый локоть       64 non-null     int64
#  1   2D_Правый локоть      64 non-null     int64
#  2   2D_Левое плечо        64 non-null     int64
#  3   2D_Правое плечо       64 non-null     int64
#  4   2D_Левое бедро        64 non-null     int64
#  5   2D_Правое бедро       64 non-null     int64
#  6   2D_Левое колено       64 non-null     int64
#  7   2D_Правое колено      64 non-null     int64
#  8   2D_Левый голеностоп   64 non-null     int64
#  9   2D_Правый голеностоп  64 non-null     int64
#  10  2D_Левое запястье     64 non-null     int64
#  11  2D_Правое запястье    64 non-null     int64
#  12  3D_Левый локоть       64 non-null     int64
#  13  3D_Правый локоть      64 non-null     int64
#  14  3D_Левое плечо        64 non-null     int64
#  15  3D_Правое плечо       64 non-null     int64
#  16  3D_Левое бедро        64 non-null     int64
#  17  3D_Правое бедро       64 non-null     int64
#  18  3D_Левое колено       64 non-null     int64
#  19  3D_Правое колено      64 non-null     int64
#  20  3D_Левый голеностоп   64 non-null     int64
#  21  3D_Правый голеностоп  64 non-null     int64
#  22  3D_Левое запястье     64 non-null     int64
#  23  3D_Правое запястье    64 non-null     int64
#  24  X-angle               64 non-null     float64
#  25  Time                  64 non-null     float64
# dtypes: float64(2), int64(24)
# memory usage: 13.1 KB

# %%
df.describe()
# Out:
#        2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# count        64.000000         64.000000       64.000000        64.000000
# mean         64.046875         62.937500       77.578125        82.812500
# std          35.997103         44.920697       36.532571        48.734745
# min          14.000000          1.000000        0.000000         0.000000
# 25%          38.000000         15.750000       55.750000        43.500000
# 50%          51.000000         63.000000       76.000000        74.000000
# 75%          86.500000         99.250000       93.000000       117.000000
# max         172.000000        159.000000      179.000000       179.000000
#
#        2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# count       64.000000        64.000000        64.000000         64.000000
# mean        50.859375        42.640625        52.984375         64.546875
# std         27.944882        30.636821        32.726133         31.982599
# min          1.000000         3.000000         1.000000          4.000000
# 25%         33.500000        18.000000        29.750000         48.000000
# 50%         54.500000        31.000000        47.000000         55.000000
# 75%         66.250000        57.000000        68.500000         73.000000
# max        143.000000       109.000000       165.000000        146.000000
#
#        2D_Левый голеностоп  2D_Правый голеностоп  ...  3D_Левое бедро  \
# count            64.000000             64.000000  ...       64.000000
# mean             42.578125             27.843750  ...       56.250000
# std              27.820744             15.103052  ...       20.124217
# min               2.000000              1.000000  ...        9.000000
# 25%              27.000000             17.500000  ...       41.750000
# 50%              40.000000             28.000000  ...       55.500000
# 75%              49.000000             37.000000  ...       73.250000
# max             178.000000             88.000000  ...       97.000000
#
#        3D_Правое бедро  3D_Левое колено  3D_Правое колено  \
# count        64.000000        64.000000         64.000000
# mean         47.375000        67.265625         65.500000
# std          23.556417        29.518486         30.863242
# min           9.000000         1.000000         28.000000
# 25%          30.750000        49.000000         43.750000
# 50%          41.500000        67.500000         53.000000
# 75%          64.000000        88.250000         84.500000
# max         109.000000       128.000000        145.000000
#
#        3D_Левый голеностоп  3D_Правый голеностоп  3D_Левое запястье  \
# count            64.000000             64.000000          64.000000
# mean             35.390625             29.859375          33.859375
# std              13.717810             13.495287          33.097675
# min              16.000000             12.000000           6.000000
# 25%              26.000000             20.750000          13.750000
# 50%              37.000000             27.000000          18.000000
# 75%              42.000000             38.000000          38.500000
# max             105.000000             87.000000         136.000000
#
#        3D_Правое запястье    X-angle          Time
# count           64.000000  64.000000  6.400000e+01
# mean            49.625000   6.078675  1.696435e+09
# std             30.183828   7.354268  3.819573e+00
# min              4.000000   0.576323  1.696435e+09
# 25%             24.750000   2.500066  1.696435e+09
# 50%             51.500000   3.049848  1.696435e+09
# 75%             71.250000   7.401272  1.696435e+09
# max            152.000000  45.869093  1.696435e+09
#
# [8 rows x 26 columns]

# %%
df[['3D_Левое бедро', '3D_Правое бедро', 'X-angle']].describe()
# Out:
#        3D_Левое бедро  3D_Правое бедро    X-angle
# count       64.000000        64.000000  64.000000
# mean        56.250000        47.375000   6.078675
# std         20.124217        23.556417   7.354268
# min          9.000000         9.000000   0.576323
# 25%         41.750000        30.750000   2.500066
# 50%         55.500000        41.500000   3.049848
# 75%         73.250000        64.000000   7.401272
# max         97.000000       109.000000  45.869093

# %%
df14_des = df.describe()
df14_des.to_excel('df14.xlsx')

# %%
df.columns
# Out:
# Index(['2D_Левый локоть', '2D_Правый локоть', '2D_Левое плечо',
#        '2D_Правое плечо', '2D_Левое бедро', '2D_Правое бедро',
#        '2D_Левое колено', '2D_Правое колено', '2D_Левый голеностоп',
#        '2D_Правый голеностоп', '2D_Левое запястье', '2D_Правое запястье',
#        '3D_Левый локоть', '3D_Правый локоть', '3D_Левое плечо',
#        '3D_Правое плечо', '3D_Левое бедро', '3D_Правое бедро',
#        '3D_Левое колено', '3D_Правое колено', '3D_Левый голеностоп',
#        '3D_Правый голеностоп', '3D_Левое запястье', '3D_Правое запястье',
#        'X-angle', 'Time'],
#       dtype='object')

# %%
df[['3D_Левое бедро','3D_Левое колено']].corr()
# Out:
#                  3D_Левое бедро  3D_Левое колено
# 3D_Левое бедро         1.000000         0.467337
# 3D_Левое колено        0.467337         1.000000

# %%
df[['3D_Правое колено','3D_Правое бедро']].corr()
# Out:
#                   3D_Правое колено  3D_Правое бедро
# 3D_Правое колено          1.000000         0.135756
# 3D_Правое бедро           0.135756         1.000000

# %%
left=df[['3D_Левое бедро','3D_Левое колено']]
left
# Out:
#     3D_Левое бедро  3D_Левое колено
# 0               61               63
# 1               64               72
# 2               68               81
# 3               76               87
# 4               70               89
# ..             ...              ...
# 59              33               57
# 60              55               72
# 61              36               48
# 62              43               75
# 63              80               85
#
# [64 rows x 2 columns]

# %%
right = df[['3D_Правое колено','3D_Правое бедро']]
right
# Out:
#     3D_Правое колено  3D_Правое бедро
# 0                 40               75
# 1                 30               76
# 2                 41               74
# 3                 47               74
# 4                 54               81
# ..               ...              ...
# 59                30               23
# 60                50               46
# 61                30               25
# 62                52               30
# 63                60               58
#
# [64 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
#plt.tick_params = 10
left.plot(figsize = (14, 8), grid=True)
# Out:
# <Axes: >

# %%
l_sgl= left.iloc[:38].ewm(com=5).mean()

# %%
l_sgl.plot(figsize = (14, 8), grid=True)
# Out:
# <Axes: >

# %%
l_sgl.corr()
# Out:
#                  3D_Левое бедро  3D_Левое колено
# 3D_Левое бедро         1.000000         0.905571
# 3D_Левое колено        0.905571         1.000000

# %% [markdown]
# # Разное

# %%
df14[['3D_Левое бедро','3D_Правое бедро']].plot(figsize = (12, 6), kind='box')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
B = df14[['3D_Левое бедро','3D_Правое бедро']]
B
# Out:
#       3D_Левое бедро  3D_Правое бедро
# 0                 24               10
# 1                 23                8
# 2                 22                7
# 3                 23                7
# 4                 23                6
# ...              ...              ...
# 1034              21               52
# 1035              19               51
# 1036              14               56
# 1037              13               49
# 1038               9               39
#
# [1039 rows x 2 columns]

# %%
B.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Выделение отдельных бросков

# %%
A1 = B.iloc[100:228]
A1
# Out:
#      3D_Левое бедро  3D_Правое бедро
# 100              21               16
# 101              22               18
# 102              27               18
# 103              31               16
# 104              31               15
# ..              ...              ...
# 223              45               52
# 224              38               51
# 225              26               46
# 226              24               39
# 227              20               39
#
# [128 rows x 2 columns]

# %%
A1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
A11 = A1.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
A11.corr()
# Out:
#           lefthip  righthip
# lefthip      1.00      0.31
# righthip     0.31      1.00

# %%
A11.describe()
# Out:
#        lefthip  righthip
# count   128.00    128.00
# mean     85.81     58.24
# std      40.39     23.43
# min      20.00     15.00
# 25%      48.25     38.00
# 50%      87.50     63.50
# 75%     116.75     77.00
# max     148.00     99.00

# %%
A11.plot(figsize = (12, 6), kind='box')
# Out:
# <AxesSubplot:>

# %%
A2 = B.iloc[369:506]
A2
# Out:
#      3D_Левое бедро  3D_Правое бедро
# 369              28               24
# 370              28               34
# 371              25               31
# 372              25               30
# 373              25               28
# ..              ...              ...
# 501              26               26
# 502              25               19
# 503              23               24
# 504              19               17
# 505              18               19
#
# [137 rows x 2 columns]

# %%
A21 = A2.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
A21.describe()
# Out:
#        lefthip  righthip
# count   137.00    137.00
# mean     82.18     60.72
# std      41.35     31.38
# min      18.00     15.00
# 25%      42.00     31.00
# 50%      87.00     56.00
# 75%     115.00     87.00
# max     145.00    137.00

# %%
A3 = B.iloc[638:770]
A3
# Out:
#      3D_Левое бедро  3D_Правое бедро
# 638              21               22
# 639              21               21
# 640              26               26
# 641              33               31
# 642              34               39
# ..              ...              ...
# 765              48                9
# 766              26                8
# 767              22               10
# 768              32               14
# 769              31               17
#
# [132 rows x 2 columns]

# %%
A31 = A3.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
A31.describe()
# Out:
#        lefthip  righthip
# count   132.00    132.00
# mean     76.70     56.69
# std      40.13     23.89
# min       7.00      8.00
# 25%      45.00     37.75
# 50%      80.00     59.00
# 75%     106.25     76.50
# max     143.00    112.00

# %%
A4 = B.iloc[898:1019]
A4
# Out:
#       3D_Левое бедро  3D_Правое бедро
# 898               24               21
# 899               29               21
# 900               34               27
# 901               47               40
# 902               52               50
# ...              ...              ...
# 1014              21               32
# 1015              21               35
# 1016              21               41
# 1017              23               43
# 1018              21               47
#
# [121 rows x 2 columns]

# %%
A4.describe()
# Out:
#        3D_Левое бедро  3D_Правое бедро
# count          121.00           121.00
# mean            89.47            58.45
# std             45.60            25.20
# min             21.00            21.00
# 25%             49.00            34.00
# 50%             85.00            58.00
# 75%            140.00            77.00
# max            156.00           127.00

# %% [markdown]
# # Статистический анализ

# %%
A41 = A4.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["lefthip"], A21["lefthip"], A31["lefthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=3.482, p=0.175
# Same distributions (fail to reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["righthip"], A21["righthip"], A31["righthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=0.856, p=0.652
# Same distributions (fail to reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["lefthip"], A11["righthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=33.810, p=0.000
# Different distributions (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["righthip"], A21["righthip"], A31["righthip"],A11["lefthip"], A21["lefthip"], A31["lefthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=71.483, p=0.000
# Different distributions (reject H0)

# %%
A11.corr()
# Out:
#           lefthip  righthip
# lefthip      1.00      0.31
# righthip     0.31      1.00

# %%
A21.corr()
# Out:
#           lefthip  righthip
# lefthip      1.00      0.31
# righthip     0.31      1.00

# %%
A31.corr()
# Out:
#           lefthip  righthip
# lefthip      1.00      0.35
# righthip     0.35      1.00

# %%
B.corr()
# Out:
#                  3D_Левое бедро  3D_Правое бедро
# 3D_Левое бедро             1.00             0.64
# 3D_Правое бедро            0.64             1.00

# %%
pd.concat([A1, A2, A3]).corr()
# Out:
#                  3D_Левое бедро  3D_Правое бедро
# 3D_Левое бедро             1.00             0.32
# 3D_Правое бедро            0.32             1.00

# %% [markdown]
# # Построение регрессии для полного движения первого броска

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
y = A11.iloc[:,1:2].values
X = A11.iloc[:,0:1].values

# %%
A11.iloc[:,1:2]
# Out:
#      righthip
# 100        16
# 101        18
# 102        18
# 103        16
# 104        15
# ..        ...
# 223        52
# 224        51
# 225        46
# 226        39
# 227        39
#
# [128 rows x 1 columns]

# %%
A11.iloc[:,0:1]
# Out:
#      lefthip
# 100       21
# 101       22
# 102       27
# 103       31
# 104       31
# ..       ...
# 223       45
# 224       38
# 225       26
# 226       24
# 227       20
#
# [128 rows x 1 columns]

# %%
lin_reg = LinearRegression()
lin_reg.fit(X,y)
lin_reg.coef_
# Out:
# array([[0.18141192]])

# %%
plt.scatter(X,y, color='red')
plt.plot(X, lin_reg.predict(X),color='blue')
plt.title("Linear")
plt.ylabel('Правое бедро')
plt.xlabel('Левое бедро')
plt.show()

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)
lin_reg2.coef_
# Out:
# array([[ 0.        ,  2.37268614, -0.01311694]])

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)

plt.figsize = (12, 6)
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y, color='red')

plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)),color='blue')

#plt.title("Polynomial")
plt.ylabel('Правое бедро')
plt.xlabel('Левое бедро')
plt.show()

# %%
y_poly_pred = lin_reg2.predict(X_poly)
r2_score(y, y_poly_pred)
# Out:
# 0.7258736880099964

# %%
np.sqrt(mean_squared_error(y, y_poly_pred))
# Out:
# 12.220734585686955

# %%
for i in range(2,20):

  poly_reg = PolynomialFeatures(degree=i)
  X_poly = poly_reg.fit_transform(X)
  lin_regN = LinearRegression()
  lin_regN.fit(X_poly,y)
  print(i,r2_score(y, lin_regN.predict(X_poly)), np.sqrt(mean_squared_error(y, lin_regN.predict(X_poly))))
# Out:
# 2 0.7258736880099964 12.220734585686955
# 3 0.7480862819015195 11.715150153880828
# 4 0.7508856172543061 11.649877310162774
# 5 0.7516700888081999 11.631519872553719
# 6 0.8031771281640537 10.355229597148663
# 7 0.7856674604517465 10.806025929282708
# 8 0.776299061942969 11.03966393645138
# 9 0.7834884232179665 10.860817393842735
# 10 0.7851556725670876 10.818919668378745
# 11 0.7644379835459174 11.328556684224987
# 12 0.7286695680399649 12.158253761006614
# 13 0.6957149202060791 12.875445928182263
# 14 0.6705074228538517 13.398147912880555
# 15 0.5812615560205732 15.104048373059733
# 16 0.552669744945929 15.611192776177138
# 17 0.5241271523794702 16.101539922348273
# 18 0.49663032446212685 16.560196084072665
# 19 0.4706350308954549 16.98241891158282

# %% [markdown]
# # Регрессия для серии из 4-х бросков без купюр

# %%
y = B['3D_Левое бедро']
X = B['3D_Правое бедро']

# %%
y = B.iloc[:,1:2].values
X = B.iloc[:,0:1].values
y
# Out:
# array([[10],
#        [ 8],
#        [ 7],
#        ...,
#        [56],
#        [49],
#        [39]])

# %%
lin_reg = LinearRegression()
lin_reg.fit(X,y)
lin_reg.coef_
# Out:
# array([[0.4178247]])

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)
lin_reg2.coef_
# Out:
# array([[ 0.        ,  1.87149299, -0.01010053]])

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)

plt.figsize = (12, 6)
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y, color='red')

plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)),color='blue')

#plt.title("Polynomial")
plt.ylabel('Правое бедро')
plt.xlabel('Левое бедро')
plt.show()

# %%
y_poly_pred = lin_reg2.predict(X_poly)
r2_score(y, y_poly_pred)
# Out:
# 0.6643618817359491

# %% [markdown]
# # Регрессия для активной части первого броска

# %%
A11.plot()
# Out:
# <AxesSubplot:>

# %%
A11[10:110].plot()
# Out:
# <AxesSubplot:>

# %%
HLF = A11[10:110]

# %%
y = HLF.iloc[:,1:2].values
X = HLF.iloc[:,0:1].values

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)
lin_reg2.coef_
# Out:
# array([[ 0.        ,  2.30207332, -0.01289525]])

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)

plt.figsize = (12, 6)
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y, color='red')

plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)),color='blue')

#plt.title("Polynomial")
plt.ylabel('Правое бедро')
plt.xlabel('Левое бедро')
plt.show()

# %%
y_poly_pred = lin_reg2.predict(X_poly)
r2_score(y, y_poly_pred)
# Out:
# 0.6883960456404762

# %%
np.sqrt(mean_squared_error(y, y_poly_pred))
# Out:
# 12.009977922082204

# %% [markdown]
# # Регрессия для активной части первого броска со сглаживанием

# %%
df14[['3D_Левое бедро','3D_Правое бедро']].ewm(com=5).mean().plot()
# Out:
# <AxesSubplot:>

# %%
A11.plot()
# Out:
# <AxesSubplot:>

# %%
A11[10:110].plot()
# Out:
# <AxesSubplot:>

# %%
HLF = A11[10:110]
HLF = HLF.ewm(com=5).mean()

# %%
HLF.plot()
# Out:
# <AxesSubplot:>

# %%
y = HLF.iloc[:,1:2].values
X = HLF.iloc[:,0:1].values

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)
lin_reg2.coef_
# Out:
# array([[ 0.        ,  2.51651746, -0.01397172]])

# %%
2.51468013-0.01400068*40
# Out:
# 1.95465293

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)

plt.figsize = (12, 6)
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y, color='red')

plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)),color='blue')

#plt.title("Polynomial")
plt.ylabel('Правое бедро')
plt.xlabel('Левое бедро')
plt.show()

# %%
y_poly_pred = lin_reg2.predict(X_poly)
r2_score(y, y_poly_pred)
# Out:
# 0.9061678274474265

# %%
np.sqrt(mean_squared_error(y, y_poly_pred))
# Out:
# 5.676265443847587
