# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ![задание](https://raw.githubusercontent.com/vn322/Sport-University/main/Screenshot_4.jpg)

# %%
 df14 = pd.read_excel('/content/1714.xlsx', index_col=None) 
 df14
# Out:
#       2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# 0                   4                 4               0                7
# 1                   3                 4               0                7
# 2                   4                 5               0                7
# 3                   4                 4               1                7
# 4                   4                 4               1                7
# ...               ...               ...             ...              ...
# 1034               10                12               2                2
# 1035               12                10               1                1
# 1036               11                 9               1                0
# 1037               10                 8               0                0
# 1038               10                 8               1                0
#
#       2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# 0                  6                2                3                 6
# 1                  7                3                4                 6
# 2                  7                3                4                 6
# 3                  7                3                4                 6
# 4                  7                3                5                 6
# ...              ...              ...              ...               ...
# 1034               1                1                1                38
# 1035               1                1                3                36
# 1036               1                1                4                35
# 1037               2                2                3                33
# 1038               2                2                2                30
#
#       2D_Левый голеностоп  2D_Правый голеностоп  ...  3D_Левое плечо  \
# 0                      14                    14  ...              46
# 1                      12                    14  ...              37
# 2                      13                    14  ...              36
# 3                      14                    15  ...              36
# 4                      14                    15  ...              37
# ...                   ...                   ...  ...             ...
# 1034                   15                    60  ...              19
# 1035                   15                    58  ...              18
# 1036                   16                    58  ...              17
# 1037                   16                    49  ...              17
# 1038                   16                    53  ...              15
#
#       3D_Правое плечо  3D_Левое бедро  3D_Правое бедро  3D_Левое колено  \
# 0                  27              24               10               17
# 1                  26              23                8               19
# 2                  27              22                7               20
# 3                  25              23                7               19
# 4                  24              23                6               19
# ...               ...             ...              ...              ...
# 1034               42              21               52               33
# 1035               45              19               51               34
# 1036               42              14               56               36
# 1037               42              13               49               32
# 1038               43               9               39               26
#
#       3D_Правое колено  3D_Левый голеностоп  3D_Правый голеностоп  \
# 0                   17                   22                    23
# 1                   20                   22                    23
# 2                   22                   22                    23
# 3                   23                   23                    24
# 4                   24                   23                    24
# ...                ...                  ...                   ...
# 1034                63                   25                    53
# 1035                63                   24                    49
# 1036                68                   29                    46
# 1037                64                   29                    37
# 1038                55                   28                    40
#
#       3D_Левое запястье  3D_Правое запястье
# 0                    35                  18
# 1                    41                  17
# 2                    41                  17
# 3                    40                  17
# 4                    40                  17
# ...                 ...                 ...
# 1034                 15                  40
# 1035                 17                  42
# 1036                 18                  38
# 1037                 18                  38
# 1038                 17                  37
#
# [1039 rows x 24 columns]

# %%
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   2D_Левый локоть       1039 non-null   int64
#  1   2D_Правый локоть      1039 non-null   int64
#  2   2D_Левое плечо        1039 non-null   int64
#  3   2D_Правое плечо       1039 non-null   int64
#  4   2D_Левое бедро        1039 non-null   int64
#  5   2D_Правое бедро       1039 non-null   int64
#  6   2D_Левое колено       1039 non-null   int64
#  7   2D_Правое колено      1039 non-null   int64
#  8   2D_Левый голеностоп   1039 non-null   int64
#  9   2D_Правый голеностоп  1039 non-null   int64
#  10  2D_Левое запястье     1039 non-null   int64
#  11  2D_Правое запястье    1039 non-null   int64
#  12  3D_Левый локоть       1039 non-null   int64
#  13  3D_Правый локоть      1039 non-null   int64
#  14  3D_Левое плечо        1039 non-null   int64
#  15  3D_Правое плечо       1039 non-null   int64
#  16  3D_Левое бедро        1039 non-null   int64
#  17  3D_Правое бедро       1039 non-null   int64
#  18  3D_Левое колено       1039 non-null   int64
#  19  3D_Правое колено      1039 non-null   int64
#  20  3D_Левый голеностоп   1039 non-null   int64
#  21  3D_Правый голеностоп  1039 non-null   int64
#  22  3D_Левое запястье     1039 non-null   int64
#  23  3D_Правое запястье    1039 non-null   int64
# dtypes: int64(24)
# memory usage: 194.9 KB

# %%
df14.describe()
# Out:
#        2D_Левый локоть  2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  \
# count      1039.000000       1039.000000     1039.000000      1039.000000
# mean         49.963426         71.986526       41.408085        38.589990
# std          54.777344         60.451846       46.904435        35.064314
# min           1.000000          1.000000        0.000000         0.000000
# 25%           9.000000         11.000000        4.000000         9.000000
# 50%          20.000000         65.000000       20.000000        28.000000
# 75%          87.000000        127.000000       66.000000        55.000000
# max         180.000000        180.000000      179.000000       179.000000
#
#        2D_Левое бедро  2D_Правое бедро  2D_Левое колено  2D_Правое колено  \
# count     1039.000000      1039.000000      1039.000000       1039.000000
# mean        38.414822        15.505294         7.580366         10.352262
# std         50.128930        16.038601         8.196352          8.481935
# min          1.000000         1.000000         1.000000          1.000000
# 25%          7.000000         4.000000         3.000000          4.000000
# 50%         11.000000        11.000000         4.000000          7.000000
# 75%         46.000000        21.000000         8.000000         15.000000
# max        158.000000        89.000000        41.000000         41.000000
#
#        2D_Левый голеностоп  2D_Правый голеностоп  ...  3D_Левое плечо  \
# count          1039.000000           1039.000000  ...     1039.000000
# mean             18.490857             20.450433  ...       68.223292
# std              14.212456             11.821130  ...       36.169029
# min               1.000000              1.000000  ...       10.000000
# 25%              10.000000             14.000000  ...       38.000000
# 50%              16.000000             18.000000  ...       56.000000
# 75%              21.000000             24.000000  ...      103.000000
# max             119.000000             86.000000  ...      147.000000
#
#        3D_Правое плечо  3D_Левое бедро  3D_Правое бедро  3D_Левое колено  \
# count      1039.000000     1039.000000      1039.000000      1039.000000
# mean         63.856593       50.751684        37.693936        31.256978
# std          39.858198       44.222462        28.830524        21.842852
# min           9.000000        3.000000         1.000000         1.000000
# 25%          30.000000       18.000000        15.000000        16.000000
# 50%          48.000000       26.000000        27.000000        24.000000
# 75%          99.000000       85.000000        59.000000        42.000000
# max         168.000000      156.000000       137.000000       109.000000
#
#        3D_Правое колено  3D_Левый голеностоп  3D_Правый голеностоп  \
# count       1039.000000          1039.000000           1039.000000
# mean          38.408085            24.432146             26.728585
# std           21.110202             9.661165              8.934328
# min            3.000000             6.000000              2.000000
# 25%           21.000000            19.000000             22.000000
# 50%           34.000000            23.000000             25.000000
# 75%           53.000000            26.000000             30.000000
# max          111.000000           105.000000             80.000000
#
#        3D_Левое запястье  3D_Правое запястье
# count        1039.000000         1039.000000
# mean           21.333975           25.046198
# std            12.496054           20.815128
# min             1.000000            1.000000
# 25%            12.000000           13.000000
# 50%            20.000000           18.000000
# 75%            28.000000           29.000000
# max           149.000000          157.000000
#
# [8 rows x 24 columns]

# %%
df14[['3D_Левое бедро', '3D_Правое бедро']].describe()
# Out:
#        3D_Левое бедро  3D_Правое бедро
# count     1039.000000      1039.000000
# mean        50.751684        37.693936
# std         44.222462        28.830524
# min          3.000000         1.000000
# 25%         18.000000        15.000000
# 50%         26.000000        27.000000
# 75%         85.000000        59.000000
# max        156.000000       137.000000

# %%
df14_des = df14.describe()
df14_des.to_excel('df14.xlsx')

# %%
df14_des.columns
# Out:
# Index(['2D_Левый локоть', '2D_Правый локоть', '2D_Левое плечо',
#        '2D_Правое плечо', '2D_Левое бедро', '2D_Правое бедро',
#        '2D_Левое колено', '2D_Правое колено', '2D_Левый голеностоп',
#        '2D_Правый голеностоп', '2D_Левое запястье', '2D_Правое запястье',
#        '3D_Левый локоть', '3D_Правый локоть', '3D_Левое плечо',
#        '3D_Правое плечо', '3D_Левое бедро', '3D_Правое бедро',
#        '3D_Левое колено', '3D_Правое колено', '3D_Левый голеностоп',
#        '3D_Правый голеностоп', '3D_Левое запястье', '3D_Правое запястье'],
#       dtype='object')

# %%
df14[['2D_Правое бедро','3D_Правое бедро']]
# Out:
#       2D_Правое бедро  3D_Правое бедро
# 0                   2               10
# 1                   3                8
# 2                   3                7
# 3                   3                7
# 4                   3                6
# ...               ...              ...
# 1034                1               52
# 1035                1               51
# 1036                1               56
# 1037                2               49
# 1038                2               39
#
# [1039 rows x 2 columns]

# %%
df2 = df14.rename(columns={'2D_Правое бедро': "2righthip", '3D_Правое бедро': "3righthip"}, errors="raise")

# %%
df2['2righthip']
# Out:
# 0       2
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1034    1
# 1035    1
# 1036    1
# 1037    2
# 1038    2
# Name: 2righthip, Length: 1039, dtype: int64

# %%
df14[['3D_Левое бедро','3D_Правое бедро']].corr()
# Out:
#                  3D_Левое бедро  3D_Правое бедро
# 3D_Левое бедро         1.000000         0.640891
# 3D_Правое бедро        0.640891         1.000000

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
#plt.tick_params = 10
df14[['3D_Левое бедро','3D_Правое бедро']].plot(figsize = (14, 8), grid=True)

# %%
df14[['3D_Левое бедро','3D_Правое бедро']].plot(figsize = (12, 6), kind='box')

# %%
plt.figure(figsize = (12, 6))
df14[['3D_Левое бедро','3D_Правое бедро']].boxplot()

# %%
import seaborn as sns

# %%
B = df14[['3D_Левое бедро','3D_Правое бедро']]
B
# Out:
#       3D_Левое бедро  3D_Правое бедро
# 0                 24               10
# 1                 23                8
# 2                 22                7
# 3                 23                7
# 4                 23                6
# ...              ...              ...
# 1034              21               52
# 1035              19               51
# 1036              14               56
# 1037              13               49
# 1038               9               39
#
# [1039 rows x 2 columns]

# %%
B.plot.kde()

# %%
A1 = B.iloc[100:228]
A1
# Out:
#      3D_Левое бедро  3D_Правое бедро
# 100              21               16
# 101              22               18
# 102              27               18
# 103              31               16
# 104              31               15
# ..              ...              ...
# 223              45               52
# 224              38               51
# 225              26               46
# 226              24               39
# 227              20               39
#
# [128 rows x 2 columns]

# %%
A1.plot.kde()

# %%
A11 = A1.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
A11.corr()
# Out:
#            lefthip  righthip
# lefthip   1.000000  0.312722
# righthip  0.312722  1.000000

# %%
A11.describe()
# Out:
#           lefthip    righthip
# count  128.000000  128.000000
# mean    85.812500   58.242188
# std     40.394073   23.432848
# min     20.000000   15.000000
# 25%     48.250000   38.000000
# 50%     87.500000   63.500000
# 75%    116.750000   77.000000
# max    148.000000   99.000000

# %%
A11.plot(figsize = (12, 6), kind='box')

# %%
A2 = B.iloc[369:506]
A2
# Out:
#      3D_Левое бедро  3D_Правое бедро
# 369              28               24
# 370              28               34
# 371              25               31
# 372              25               30
# 373              25               28
# ..              ...              ...
# 501              26               26
# 502              25               19
# 503              23               24
# 504              19               17
# 505              18               19
#
# [137 rows x 2 columns]

# %%
A21 = A2.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
A21.describe()
# Out:
#           lefthip    righthip
# count  137.000000  137.000000
# mean    82.182482   60.715328
# std     41.350051   31.378137
# min     18.000000   15.000000
# 25%     42.000000   31.000000
# 50%     87.000000   56.000000
# 75%    115.000000   87.000000
# max    145.000000  137.000000

# %%
A3 = B.iloc[638:770]
A3
# Out:
#      3D_Левое бедро  3D_Правое бедро
# 638              21               22
# 639              21               21
# 640              26               26
# 641              33               31
# 642              34               39
# ..              ...              ...
# 765              48                9
# 766              26                8
# 767              22               10
# 768              32               14
# 769              31               17
#
# [132 rows x 2 columns]

# %%
A31 = A3.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
A31.describe()
# Out:
#           lefthip    righthip
# count  132.000000  132.000000
# mean    76.696970   56.689394
# std     40.133354   23.889099
# min      7.000000    8.000000
# 25%     45.000000   37.750000
# 50%     80.000000   59.000000
# 75%    106.250000   76.500000
# max    143.000000  112.000000

# %%
A4 = B.iloc[898:1019]
A4
# Out:
#       3D_Левое бедро  3D_Правое бедро
# 898               24               21
# 899               29               21
# 900               34               27
# 901               47               40
# 902               52               50
# ...              ...              ...
# 1014              21               32
# 1015              21               35
# 1016              21               41
# 1017              23               43
# 1018              21               47
#
# [121 rows x 2 columns]

# %%
A4.describe()
# Out:
#        3D_Левое бедро  3D_Правое бедро
# count      121.000000       121.000000
# mean        89.471074        58.446281
# std         45.595152        25.200182
# min         21.000000        21.000000
# 25%         49.000000        34.000000
# 50%         85.000000        58.000000
# 75%        140.000000        77.000000
# max        156.000000       127.000000

# %%
A41 = A4.rename(columns={'3D_Левое бедро': "lefthip", '3D_Правое бедро': "righthip"}, errors="raise")

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["lefthip"], A21["lefthip"], A31["lefthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=3.482, p=0.175
# Same distributions (fail to reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["righthip"], A21["righthip"], A31["righthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=0.856, p=0.652
# Same distributions (fail to reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["lefthip"], A11["righthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=33.810, p=0.000
# Different distributions (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(A11["righthip"], A21["righthip"], A31["righthip"],A11["lefthip"], A21["lefthip"], A31["lefthip"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=71.483, p=0.000
# Different distributions (reject H0)

# %%
A11.corr()
# Out:
#            lefthip  righthip
# lefthip   1.000000  0.312722
# righthip  0.312722  1.000000

# %%
A21.corr()
# Out:
#            lefthip  righthip
# lefthip   1.000000  0.309995
# righthip  0.309995  1.000000

# %%
A31.corr()
# Out:
#            lefthip  righthip
# lefthip   1.000000  0.346727
# righthip  0.346727  1.000000

# %%
B.corr()
# Out:
#                  3D_Левое бедро  3D_Правое бедро
# 3D_Левое бедро         1.000000         0.640891
# 3D_Правое бедро        0.640891         1.000000

# %%
pd.concat([A1, A2, A3]).corr()
# Out:
#                  3D_Левое бедро  3D_Правое бедро
# 3D_Левое бедро         1.000000         0.320004
# 3D_Правое бедро        0.320004         1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
'''
polynomial_features = PolynomialFeatures(degree=2) # указываем вторую степень полинома
x_poly = polynomial_features.fit_transform(A11) # получаем новые признаки
'''
# Out:
# '\npolynomial_features = PolynomialFeatures(degree=2) # указываем вторую степень полинома\nx_poly = polynomial_features.fit_transform(A11) # получаем новые признаки\n'

# %%
y = A11.iloc[:,1:2].values
X = A11.iloc[:,0:1].values

# %%
A11
# Out:
#      lefthip  righthip
# 100       21        16
# 101       22        18
# 102       27        18
# 103       31        16
# 104       31        15
# ..       ...       ...
# 223       45        52
# 224       38        51
# 225       26        46
# 226       24        39
# 227       20        39
#
# [128 rows x 2 columns]

# %%
A11.iloc[:,1:2]
# Out:
#      righthip
# 100        16
# 101        18
# 102        18
# 103        16
# 104        15
# ..        ...
# 223        52
# 224        51
# 225        46
# 226        39
# 227        39
#
# [128 rows x 1 columns]

# %%
A11.iloc[:,0:1]
# Out:
#      lefthip
# 100       21
# 101       22
# 102       27
# 103       31
# 104       31
# ..       ...
# 223       45
# 224       38
# 225       26
# 226       24
# 227       20
#
# [128 rows x 1 columns]

# %%
lin_reg = LinearRegression()
lin_reg.fit(X,y)
lin_reg.coef_
# Out:
# array([[0.18141192]])

# %%
plt.scatter(X,y, color='red')
plt.plot(X, lin_reg.predict(X),color='blue')
plt.title("Linear")
plt.ylabel('Правое бедро')
plt.xlabel('Левое бедро')
plt.show()

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)
lin_reg2.coef_
# Out:
# array([[ 0.        ,  2.37268614, -0.01311694]])

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)

plt.figsize = (12, 6) 
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1) 
plt.scatter(X,y, color='red') 
 
plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)),color='blue') 
 
#plt.title("Polynomial")
plt.ylabel('Правое бедро')
plt.xlabel('Левое бедро')
plt.show()

# %%
y_poly_pred = lin_reg2.predict(X_poly)
r2_score(y, y_poly_pred)
# Out:
# 0.7258736880099965

# %%
np.sqrt(mean_squared_error(y, y_poly_pred))
# Out:
# 12.220734585686955

# %%
for i in range(2,20):

  poly_reg = PolynomialFeatures(degree=i)
  X_poly = poly_reg.fit_transform(X)
  lin_regN = LinearRegression()
  lin_regN.fit(X_poly,y)
  print(i,r2_score(y, lin_regN.predict(X_poly)), np.sqrt(mean_squared_error(y, lin_regN.predict(X_poly))))
# Out:
# 2 0.7258736880099965 12.220734585686955
# 3 0.7480862819015195 11.715150153880828
# 4 0.7508856172543061 11.649877310162774
# 5 0.7516700888082 11.631519872553717
# 6 0.8031771281640734 10.355229597148146
# 7 0.7856674599079974 10.806025942989836
# 8 0.776299061906401 11.039663937353698
# 9 0.7834884232001446 10.860817394289732
# 10 0.7851556727560055 10.818919663622072
# 11 0.7644379706164427 11.328556995124613
# 12 0.7286695697125267 12.15825372353306
# 13 0.695716226085709 12.8754182998138
# 14 0.6705209386367967 13.39787311410101
# 15 0.5812615560203926 15.104048373062987
# 16 0.5526697449444065 15.611192776203703
# 17 0.5241271523802347 16.10153992233534
# 18 0.496630324461381 16.560196084084932
# 19 0.47063503090118763 16.982418911490864

# %%
import statsmodels.formula.api as smf

model = smf.ols('lefthip ~ righthip', data=A11)
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lefthip   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     13.66
# Date:                Wed, 28 Sep 2022   Prob (F-statistic):           0.000326
# Time:                        18:11:33   Log-Likelihood:                -647.97
# No. Observations:                 128   AIC:                             1300.
# Df Residuals:                     126   BIC:                             1306.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     54.4155      9.153      5.945      0.000      36.303      72.528
# righthip       0.5391      0.146      3.696      0.000       0.250       0.828
# ==============================================================================
# Omnibus:                       13.995   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               10.383
# Skew:                           0.582   Prob(JB):                      0.00556
# Kurtosis:                       2.231   Cond. No.                         169.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.formula.api as smf

model = smf.ols('lefthip ~ righthip', data=A21)
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lefthip   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     14.35
# Date:                Wed, 28 Sep 2022   Prob (F-statistic):           0.000227
# Time:                        18:11:33   Log-Likelihood:                -696.90
# No. Observations:                 137   AIC:                             1398.
# Df Residuals:                     135   BIC:                             1404.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     57.3796      7.364      7.792      0.000      42.816      71.943
# righthip       0.4085      0.108      3.788      0.000       0.195       0.622
# ==============================================================================
# Omnibus:                       34.260   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.938
# Skew:                           0.434   Prob(JB):                      0.00421
# Kurtosis:                       1.922   Cond. No.                         149.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.violinplot(A11["righthip"],showmeans=False, showmedians=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.90)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm->lazypredict) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lazypredict) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->lazypredict) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lazypredict) (3.1.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
df14.columns
# Out:
# Index(['2D_Левый локоть', '2D_Правый локоть', '2D_Левое плечо',
#        '2D_Правое плечо', '2D_Левое бедро', '2D_Правое бедро',
#        '2D_Левое колено', '2D_Правое колено', '2D_Левый голеностоп',
#        '2D_Правый голеностоп', '2D_Левое запястье', '2D_Правое запястье',
#        '3D_Левый локоть', '3D_Правый локоть', '3D_Левое плечо',
#        '3D_Правое плечо', '3D_Левое бедро', '3D_Правое бедро',
#        '3D_Левое колено', '3D_Правое колено', '3D_Левый голеностоп',
#        '3D_Правый голеностоп', '3D_Левое запястье', '3D_Правое запястье'],
#       dtype='object')

# %%
df14.loc[:, df14.columns != '2D_Левый локоть']
# Out:
#       2D_Правый локоть  2D_Левое плечо  2D_Правое плечо  2D_Левое бедро  \
# 0                    4               0                7               6
# 1                    4               0                7               7
# 2                    5               0                7               7
# 3                    4               1                7               7
# 4                    4               1                7               7
# ...                ...             ...              ...             ...
# 1034                12               2                2               1
# 1035                10               1                1               1
# 1036                 9               1                0               1
# 1037                 8               0                0               2
# 1038                 8               1                0               2
#
#       2D_Правое бедро  2D_Левое колено  2D_Правое колено  2D_Левый голеностоп  \
# 0                   2                3                 6                   14
# 1                   3                4                 6                   12
# 2                   3                4                 6                   13
# 3                   3                4                 6                   14
# 4                   3                5                 6                   14
# ...               ...              ...               ...                  ...
# 1034                1                1                38                   15
# 1035                1                3                36                   15
# 1036                1                4                35                   16
# 1037                2                3                33                   16
# 1038                2                2                30                   16
#
#       2D_Правый голеностоп  2D_Левое запястье  ...  3D_Левое плечо  \
# 0                       14                 13  ...              46
# 1                       14                 13  ...              37
# 2                       14                 13  ...              36
# 3                       15                 12  ...              36
# 4                       15                 12  ...              37
# ...                    ...                ...  ...             ...
# 1034                    60                  5  ...              19
# 1035                    58                  4  ...              18
# 1036                    58                  1  ...              17
# 1037                    49                  2  ...              17
# 1038                    53                  2  ...              15
#
#       3D_Правое плечо  3D_Левое бедро  3D_Правое бедро  3D_Левое колено  \
# 0                  27              24               10               17
# 1                  26              23                8               19
# 2                  27              22                7               20
# 3                  25              23                7               19
# 4                  24              23                6               19
# ...               ...             ...              ...              ...
# 1034               42              21               52               33
# 1035               45              19               51               34
# 1036               42              14               56               36
# 1037               42              13               49               32
# 1038               43               9               39               26
#
#       3D_Правое колено  3D_Левый голеностоп  3D_Правый голеностоп  \
# 0                   17                   22                    23
# 1                   20                   22                    23
# 2                   22                   22                    23
# 3                   23                   23                    24
# 4                   24                   23                    24
# ...                ...                  ...                   ...
# 1034                63                   25                    53
# 1035                63                   24                    49
# 1036                68                   29                    46
# 1037                64                   29                    37
# 1038                55                   28                    40
#
#       3D_Левое запястье  3D_Правое запястье
# 0                    35                  18
# 1                    41                  17
# 2                    41                  17
# 3                    40                  17
# 4                    40                  17
# ...                 ...                 ...
# 1034                 15                  40
# 1035                 17                  42
# 1036                 18                  38
# 1037                 18                  38
# 1038                 17                  37
#
# [1039 rows x 23 columns]

# %%
import lazypredict

from lazypredict.Supervised import LazyRegressor

from lazypredict.Supervised import LazyClassifier

# %%
X = df14[['3D_Левое бедро']]

y = df14['3D_Правое бедро']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2)

# %%
multiple_ML_model = LazyRegressor(verbose=0, ignore_warnings=True, predictions=True)

models, predictions = multiple_ML_model.fit(X_train, X_test, y_train, y_test)

models
# Out:
#  98%|█████████▊| 41/42 [00:30<00:00,  1.09it/s]
# [18:12:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 42/42 [00:30<00:00,  1.36it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# XGBRegressor                                 0.75       0.75 13.77        0.18
# GradientBoostingRegressor                    0.75       0.75 13.78        0.10
# HistGradientBoostingRegressor                0.75       0.75 13.86        0.29
# LGBMRegressor                                0.74       0.75 13.93        0.10
# BaggingRegressor                             0.74       0.74 13.99        0.03
# RandomForestRegressor                        0.74       0.74 14.00        0.37
# SVR                                          0.74       0.74 14.12        0.14
# GaussianProcessRegressor                     0.73       0.74 14.22        0.11
# ExtraTreeRegressor                           0.73       0.73 14.25        0.02
# DecisionTreeRegressor                        0.73       0.73 14.28        0.01
# NuSVR                                        0.73       0.73 14.29        0.07
# ExtraTreesRegressor                          0.73       0.73 14.33        0.11
# KNeighborsRegressor                          0.72       0.72 14.49        0.02
# AdaBoostRegressor                            0.71       0.71 14.87        0.08
# MLPRegressor                                 0.50       0.50 19.51        1.15
# LinearSVR                                    0.49       0.49 19.63        0.01
# OrthogonalMatchingPursuit                    0.49       0.49 19.68        0.01
# Lars                                         0.49       0.49 19.68        0.01
# LarsCV                                       0.49       0.49 19.68        0.02
# LassoLarsCV                                  0.49       0.49 19.68        0.01
# LassoLarsIC                                  0.49       0.49 19.68        0.01
# TransformedTargetRegressor                   0.49       0.49 19.68        0.02
# LinearRegression                             0.49       0.49 19.68        0.01
# RidgeCV                                      0.49       0.49 19.68        0.01
# Ridge                                        0.49       0.49 19.68        0.02
# BayesianRidge                                0.49       0.49 19.68        0.01
# SGDRegressor                                 0.49       0.49 19.68        0.02
# HuberRegressor                               0.49       0.49 19.69        0.02
# LassoCV                                      0.49       0.49 19.70        0.09
# ElasticNetCV                                 0.49       0.49 19.71        0.06
# Lasso                                        0.48       0.49 19.80        0.01
# PassiveAggressiveRegressor                   0.43       0.44 20.72        0.01
# ElasticNet                                   0.41       0.41 21.23        0.01
# PoissonRegressor                             0.40       0.40 21.32        0.01
# GammaRegressor                               0.34       0.35 22.33        0.01
# TweedieRegressor                             0.34       0.34 22.38        0.06
# RANSACRegressor                              0.01       0.01 27.44        0.07
# DummyRegressor                              -0.02      -0.01 27.79        0.01
# LassoLars                                   -0.02      -0.01 27.79        0.01
# QuantileRegressor                           -0.09      -0.09 28.82       27.57
# KernelRidge                                 -1.27      -1.26 41.48        0.04

# %% [markdown]
# сложная зависимость

# %%
X = df14[['3D_Правое бедро',
       '3D_Левое колено', '3D_Правое колено']]

y = df14['3D_Левое бедро']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3)

# %%
multiple_ML_model = LazyRegressor(verbose=0, ignore_warnings=True, predictions=True)

models, predictions = multiple_ML_model.fit(X_train, X_test, y_train, y_test)

models
# Out:
# 100%|██████████| 42/42 [00:22<00:00,  1.84it/s]
# [18:12:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# ExtraTreesRegressor                          0.93       0.93   12.30
# RandomForestRegressor                        0.89       0.89   14.76
# LGBMRegressor                                0.89       0.89   15.31
# HistGradientBoostingRegressor                0.88       0.89   15.32
# GradientBoostingRegressor                    0.88       0.88   15.67
# XGBRegressor                                 0.88       0.88   15.76
# BaggingRegressor                             0.88       0.88   15.89
# KNeighborsRegressor                          0.88       0.88   15.92
# AdaBoostRegressor                            0.85       0.85   17.57
# ExtraTreeRegressor                           0.85       0.85   17.69
# DecisionTreeRegressor                        0.77       0.77   21.61
# NuSVR                                        0.65       0.65   26.71
# SVR                                          0.63       0.64   27.34
# MLPRegressor                                 0.55       0.56   30.19
# LassoLarsIC                                  0.51       0.52   31.45
# TransformedTargetRegressor                   0.51       0.52   31.45
# OrthogonalMatchingPursuitCV                  0.51       0.52   31.45
# LinearRegression                             0.51       0.52   31.45
# LassoLarsCV                                  0.51       0.52   31.45
# LarsCV                                       0.51       0.52   31.45
# Lars                                         0.51       0.52   31.45
# Ridge                                        0.51       0.52   31.45
# LassoCV                                      0.51       0.52   31.46
# BayesianRidge                                0.51       0.52   31.46
# SGDRegressor                                 0.51       0.52   31.46
# RidgeCV                                      0.51       0.52   31.48
# ElasticNetCV                                 0.51       0.52   31.53
# Lasso                                        0.51       0.51   31.64
# HuberRegressor                               0.49       0.50   32.21
# LinearSVR                                    0.46       0.47   33.13
# ElasticNet                                   0.43       0.43   34.12
# OrthogonalMatchingPursuit                    0.40       0.40   35.11
# PassiveAggressiveRegressor                   0.37       0.38   35.86
# TweedieRegressor                             0.36       0.37   36.08
# GammaRegressor                               0.28       0.29   38.34
# PoissonRegressor                             0.18       0.19   40.81
# LassoLars                                    0.02       0.03   44.69
# DummyRegressor                              -0.01      -0.00   45.42
# QuantileRegressor                           -0.37      -0.36   52.91
# RANSACRegressor                             -0.70      -0.68   58.81
# KernelRidge                                 -0.77      -0.76   60.14
# GaussianProcessRegressor                 -7058.32   -6990.22 3793.69
#
#                                Time Taken
# Model
# ExtraTreesRegressor                  0.75
# RandomForestRegressor                0.28
# LGBMRegressor                        0.05
# HistGradientBoostingRegressor        2.53
# GradientBoostingRegressor            0.29
# XGBRegressor                         0.04
# BaggingRegressor                     0.05
# KNeighborsRegressor                  0.02
# AdaBoostRegressor                    0.08
# ExtraTreeRegressor                   0.02
# DecisionTreeRegressor                0.02
# NuSVR                                0.14
# SVR                                  0.05
# MLPRegressor                         2.19
# LassoLarsIC                          0.02
# TransformedTargetRegressor           0.01
# OrthogonalMatchingPursuitCV          0.04
# LinearRegression                     0.01
# LassoLarsCV                          0.03
# LarsCV                               0.02
# Lars                                 0.02
# Ridge                                0.01
# LassoCV                              0.27
# BayesianRidge                        0.02
# SGDRegressor                         0.01
# RidgeCV                              0.01
# ElasticNetCV                         0.11
# Lasso                                0.02
# HuberRegressor                       0.04
# LinearSVR                            0.01
# ElasticNet                           0.01
# OrthogonalMatchingPursuit            0.02
# PassiveAggressiveRegressor           0.02
# TweedieRegressor                     0.02
# GammaRegressor                       0.06
# PoissonRegressor                     0.02
# LassoLars                            0.04
# DummyRegressor                       0.01
# QuantileRegressor                   14.97
# RANSACRegressor                      0.06
# KernelRidge                          0.06
# GaussianProcessRegressor             0.31

# %%
predictions
# Out:
#      AdaBoostRegressor  BaggingRegressor  BayesianRidge  \
# 0                18.21             20.20          24.10
# 1               121.25            138.00          90.32
# 2                18.04             14.03          28.83
# 3                33.96             21.00          43.59
# 4                18.04             24.70          23.60
# ..                 ...               ...            ...
# 307             123.91            144.90          69.72
# 308              15.73             14.15          33.36
# 309              87.85            120.70          52.77
# 310              75.24             76.20          51.87
# 311              33.96             29.80          40.25
#
#      DecisionTreeRegressor  DummyRegressor  ElasticNet  ElasticNetCV  \
# 0                    21.00           50.12       31.12         24.61
# 1                   150.00           50.12       72.50         88.75
# 2                    16.00           50.12       33.96         29.18
# 3                     9.00           50.12       47.37         43.88
# 4                    26.00           50.12       32.64         24.35
# ..                     ...             ...         ...           ...
# 307                 141.00           50.12       58.81         68.69
# 308                  14.00           50.12       36.65         33.58
# 309                 109.00           50.12       48.70         52.35
# 310                  77.00           50.12       59.37         52.71
# 311                  28.00           50.12       47.72         40.82
#
#      ExtraTreeRegressor  ExtraTreesRegressor  GammaRegressor  ...  \
# 0                 19.00                20.04           30.44  ...
# 1                144.00               133.95           59.91  ...
# 2                 16.00                16.00           31.77  ...
# 3                 22.00                23.56           42.70  ...
# 4                 26.00                23.76           31.81  ...
# ..                  ...                  ...             ...  ...
# 307              111.00               134.03           47.45  ...
# 308               14.00                13.62           32.93  ...
# 309              139.00                85.20           40.22  ...
# 310               77.00                74.75           56.38  ...
# 311               28.00                26.97           45.59  ...
#
#      RANSACRegressor  RandomForestRegressor  Ridge  RidgeCV  SGDRegressor  \
# 0              17.80                  20.35  24.06    24.30         24.47
# 1              11.47                 137.46  90.46    89.70         90.09
# 2              16.97                  15.06  28.80    28.97         29.19
# 3              22.96                  21.78  43.56    43.71         43.23
# 4              19.61                  24.25  23.54    23.90         23.89
# ..               ...                    ...    ...      ...           ...
# 307            12.58                 138.05  69.81    69.31         69.72
# 308            15.70                  15.82  33.34    33.45         33.77
# 309            14.14                 114.26  52.80    52.60         52.96
# 310            29.88                  75.75  51.79    52.20         50.99
# 311            29.17                  29.31  40.20    40.48         39.40
#
#       SVR  TransformedTargetRegressor  TweedieRegressor  XGBRegressor  \
# 0   19.85                       24.03             34.47         17.33
# 1   92.74                       90.54             66.83        127.82
# 2   20.43                       28.78             36.62         15.34
# 3   31.30                       43.54             48.68         33.88
# 4   17.34                       23.50             36.08         14.73
# ..    ...                         ...               ...           ...
# 307 65.85                       69.86             55.93        139.40
# 308 23.06                       33.33             38.56         15.79
# 309 37.90                       52.83             48.04        114.86
# 310 70.07                       51.74             59.81         73.84
# 311 39.29                       40.16             50.17         29.87
#
#      LGBMRegressor
# 0            22.07
# 1           138.30
# 2            16.52
# 3            15.15
# 4            22.32
# ..             ...
# 307         133.30
# 308          19.79
# 309         101.26
# 310          74.88
# 311          24.81
#
# [312 rows x 42 columns]

# %%
multiple_ML_model = LazyClassifier(verbose=0, ignore_warnings=True, predictions=True)

models, predictions = multiple_ML_model.fit(X_train, X_test, y_train, y_test)

predictions
# Out:
# 100%|██████████| 29/29 [00:17<00:00,  1.63it/s]
#      AdaBoostClassifier  BaggingClassifier  BernoulliNB  \
# 0                    23                 19           17
# 1                    74                138          123
# 2                    23                 12           17
# 3                    23                 27           27
# 4                    23                 26           17
# ..                  ...                ...          ...
# 307                  23                141           27
# 308                  23                 14           17
# 309                  23                 87           17
# 310                  74                 77           74
# 311                  23                 27           27
#
#      CalibratedClassifierCV  DecisionTreeClassifier  DummyClassifier  \
# 0                        23                      21               23
# 1                       144                     136               23
# 2                        23                      16               23
# 3                        23                      22               23
# 4                        23                      26               23
# ..                      ...                     ...              ...
# 307                      17                     156               23
# 308                      17                      14               23
# 309                      17                     155               23
# 310                      74                      81               23
# 311                      31                      27               23
#
#      ExtraTreeClassifier  ExtraTreesClassifier  GaussianNB  \
# 0                     20                    20          15
# 1                    108                   136         138
# 2                     16                    16          15
# 3                    100                    27          27
# 4                     26                    26          18
# ..                   ...                   ...         ...
# 307                  140                   156         148
# 308                    7                    14          17
# 309                  155                    87          17
# 310                   77                    77          78
# 311                   27                    27          30
#
#      KNeighborsClassifier  ...  NearestCentroid  PassiveAggressiveClassifier  \
# 0                      21  ...               15                           18
# 1                     117  ...              137                          155
# 2                      14  ...               15                           18
# 3                      27  ...               28                           12
# 4                      14  ...               18                           18
# ..                    ...  ...              ...                          ...
# 307                   100  ...              150                          155
# 308                    18  ...               17                           18
# 309                    87  ...               14                           18
# 310                    80  ...               65                           96
# 311                    28  ...               30                           12
#
#      Perceptron  RandomForestClassifier  RidgeClassifier  RidgeClassifierCV  \
# 0            25                      21               23                 23
# 1           155                     136              144                144
# 2            25                      16               23                 23
# 3            47                      27               23                 23
# 4            25                      26               23                 23
# ..          ...                     ...              ...                ...
# 307          16                     156               17                 17
# 308          25                      14               23                 23
# 309          25                      87               23                 23
# 310          56                      74               74                 74
# 311          47                      27               23                 23
#
#      SGDClassifier  SVC  XGBClassifier  LGBMClassifier
# 0               24   23             21              21
# 1              144  144            140             138
# 2               24   17             14              16
# 3               10   23             28              28
# 4               23   23             24              26
# ..             ...  ...            ...             ...
# 307            146  144            125             144
# 308            146   17             14              14
# 309            146   17              8             133
# 310             10   74             74              80
# 311             10   31             28              28
#
# [312 rows x 25 columns]

# %%
models
# Out:
#                              Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# DecisionTreeClassifier           0.11               0.07    None      0.11
# BaggingClassifier                0.11               0.06    None      0.11
# KNeighborsClassifier             0.10               0.06    None      0.09
# RandomForestClassifier           0.11               0.06    None      0.11
# XGBClassifier                    0.10               0.06    None      0.10
# LGBMClassifier                   0.10               0.05    None      0.10
# ExtraTreesClassifier             0.10               0.05    None      0.11
# GaussianNB                       0.04               0.04    None      0.03
# ExtraTreeClassifier              0.09               0.04    None      0.09
# LabelSpreading                   0.06               0.04    None      0.05
# LabelPropagation                 0.06               0.03    None      0.04
# LinearDiscriminantAnalysis       0.05               0.03    None      0.02
# LogisticRegression               0.05               0.03    None      0.02
# NearestCentroid                  0.04               0.03    None      0.03
# BernoulliNB                      0.06               0.02    None      0.01
# CalibratedClassifierCV           0.04               0.02    None      0.01
# RidgeClassifier                  0.04               0.02    None      0.00
# RidgeClassifierCV                0.04               0.02    None      0.00
# SVC                              0.04               0.02    None      0.01
# LinearSVC                        0.04               0.02    None      0.01
# AdaBoostClassifier               0.03               0.02    None      0.00
# SGDClassifier                    0.02               0.02    None      0.01
# Perceptron                       0.03               0.01    None      0.01
# DummyClassifier                  0.03               0.01    None      0.00
# PassiveAggressiveClassifier      0.03               0.01    None      0.00
#
#                              Time Taken
# Model
# DecisionTreeClassifier             0.02
# BaggingClassifier                  0.07
# KNeighborsClassifier               0.02
# RandomForestClassifier             0.44
# XGBClassifier                      4.09
# LGBMClassifier                     6.43
# ExtraTreesClassifier               0.43
# GaussianNB                         0.03
# ExtraTreeClassifier                0.01
# LabelSpreading                     0.13
# LabelPropagation                   0.06
# LinearDiscriminantAnalysis         0.02
# LogisticRegression                 0.71
# NearestCentroid                    0.03
# BernoulliNB                        0.02
# CalibratedClassifierCV             3.46
# RidgeClassifier                    0.02
# RidgeClassifierCV                  0.04
# SVC                                0.19
# LinearSVC                          0.67
# AdaBoostClassifier                 0.42
# SGDClassifier                      0.20
# Perceptron                         0.10
# DummyClassifier                    0.01
# PassiveAggressiveClassifier        0.12

# %% [markdown]
# https://medium.com/@fareedkhandev/apply-40-machine-learning-models-in-two-lines-of-code-c01dad24ad99

# %% [markdown]
# https://github.com/slundberg/shap
#
#
# https://medium.com/@data.science.enthusiast/explain-any-machine-learning-model-in-python-shap-4caf1c343f3
