# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Sport-University/blob/main/Fencing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # fenc

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df_1= pd.read_csv('https://raw.githubusercontent.com/vn322/Sport-University/refs/heads/main/combat/Fence1.csv')
df_1.head(3)
# Out:
#    leftElbow  rightElbow  leftShould  rightShould  leftHip  rightHip  \
# 0         35         100          60           24        6        92
# 1         36         121          52           21       52        95
# 2         34         120          51           22       49        86
#
#    leftKnee  rightKnee  leftAnkle  rightAnkle  leftWrist  rightWrist   Xfactor
# 0        25         97         15          27         26          46  1.746339
# 1        67         95         22          27         23          23  1.658496
# 2        65         89         24          28         19          22  3.798812

# %%
df_2= pd.read_csv('https://raw.githubusercontent.com/vn322/Sport-University/refs/heads/main/combat/Fence2.csv')
df_2.head(3)
# Out:
#    leftElbow  rightElbow  leftShould  rightShould  leftHip  rightHip  \
# 0         22          93          21           19       13        59
# 1         21          92          42           25       22        57
# 2         27          99          41           22       29        57
#
#    leftKnee  rightKnee  leftAnkle  rightAnkle  leftWrist  rightWrist   Xfactor
# 0        13         44          3          16         14          59  5.050200
# 1        15         38         12          20         58          51  4.425673
# 2        15         28         14          14         56          54  5.032728

# %%
df_1.describe()
# Out:
#         leftElbow  rightElbow  leftShould  rightShould     leftHip  \
# count   74.000000   74.000000   74.000000    74.000000   74.000000
# mean    34.594595   55.594595   85.283784    35.459459   50.945946
# std     16.140580   31.386638   45.326372    18.818665   23.878627
# min      9.000000    7.000000   27.000000     7.000000    6.000000
# 25%     24.250000   33.500000   50.250000    22.000000   35.000000
# 50%     33.000000   57.000000   60.000000    30.500000   48.000000
# 75%     41.750000   70.750000  135.500000    44.000000   65.750000
# max    101.000000  121.000000  163.000000    77.000000  103.000000
#
#          rightHip    leftKnee  rightKnee  leftAnkle  rightAnkle   leftWrist  \
# count   74.000000   74.000000   74.00000  74.000000   74.000000   74.000000
# mean    76.243243   58.864865   72.27027  29.986486   30.864865   25.054054
# std     21.018459   20.070645   26.77931  14.466298    8.869409   16.421579
# min     23.000000   13.000000    5.00000   3.000000   18.000000    2.000000
# 25%     70.000000   50.000000   65.00000  23.000000   27.000000   13.250000
# 50%     76.500000   57.500000   76.50000  27.000000   29.000000   23.000000
# 75%     88.250000   69.750000   88.75000  31.000000   32.000000   34.750000
# max    132.000000  111.000000  132.00000  92.000000   74.000000  105.000000
#
#        rightWrist    Xfactor
# count   74.000000  74.000000
# mean    30.013514   7.862357
# std     17.020128   5.429499
# min      2.000000   0.853180
# 25%     22.000000   3.956677
# 50%     27.000000   5.666697
# 75%     32.000000  11.080497
# max    140.000000  29.716445

# %%
#df_3=df_1[['3D_Левый локоть', '3D_Правый локоть', '3D_Левое плечо',
       '3D_Правое плечо', '3D_Левое бедро', '3D_Правое бедро',
       '3D_Левое колено', '3D_Правое колено', 'X-angle']]

# %%
#df_3.describe()
# Out:
#        3D_Левый локоть  3D_Правый локоть  3D_Левое плечо  3D_Правое плечо  \
# count      1843.000000       1843.000000     1843.000000      1843.000000
# mean         45.578405         48.590884       88.226804        83.920781
# std          29.614400         31.289718       31.868803        33.603119
# min           1.000000          0.000000        5.000000         4.000000
# 25%          24.000000         24.000000       63.000000        59.000000
# 50%          35.000000         40.000000       91.000000        84.000000
# 75%          63.000000         67.000000      113.500000       113.000000
# max         154.000000        150.000000      157.000000       149.000000
#
#        3D_Левое бедро  3D_Правое бедро  3D_Левое колено  3D_Правое колено  \
# count     1843.000000      1843.000000      1843.000000       1843.000000
# mean        84.539338        78.343462       101.793272         85.478568
# std         30.631375        34.554019        37.804445         43.924609
# min          7.000000         3.000000         2.000000          3.000000
# 25%         62.000000        55.000000        80.000000         53.000000
# 50%         84.000000        76.000000       107.000000         88.000000
# 75%        109.000000       107.000000       132.000000        125.000000
# max        155.000000       158.000000       165.000000        160.000000
#
#            X-angle
# count  1843.000000
# mean     13.241752
# std      11.348687
# min       0.067210
# 25%       5.606081
# 50%      10.341398
# 75%      17.370461
# max      79.116426

# %% [markdown]
# ## корреляция

# %%
plt.figure(figsize=(16, 6))

# %%
df_1.corr()
# Out:
#              leftElbow  rightElbow  leftShould  rightShould   leftHip  \
# leftElbow     1.000000   -0.321488    0.133121     0.270676 -0.105441
# rightElbow   -0.321488    1.000000   -0.708565    -0.572994 -0.175843
# leftShould    0.133121   -0.708565    1.000000     0.565548  0.283206
# rightShould   0.270676   -0.572994    0.565548     1.000000 -0.022015
# leftHip      -0.105441   -0.175843    0.283206    -0.022015  1.000000
# rightHip      0.224197    0.217478   -0.305927    -0.209572  0.436266
# leftKnee     -0.055439    0.088068    0.017645    -0.186905  0.841408
# rightKnee     0.146614    0.317926   -0.355641    -0.319399  0.371209
# leftAnkle     0.086335   -0.179403    0.081232     0.296401  0.140539
# rightAnkle   -0.108134   -0.127747    0.022927     0.139242  0.150865
# leftWrist    -0.224373    0.269195   -0.540251    -0.248537 -0.235660
# rightWrist   -0.019926   -0.267626    0.213786     0.079658 -0.114126
# Xfactor       0.003277   -0.361947    0.446321     0.430423  0.521714
#
#              rightHip  leftKnee  rightKnee  leftAnkle  rightAnkle  leftWrist  \
# leftElbow    0.224197 -0.055439   0.146614   0.086335   -0.108134  -0.224373
# rightElbow   0.217478  0.088068   0.317926  -0.179403   -0.127747   0.269195
# leftShould  -0.305927  0.017645  -0.355641   0.081232    0.022927  -0.540251
# rightShould -0.209572 -0.186905  -0.319399   0.296401    0.139242  -0.248537
# leftHip      0.436266  0.841408   0.371209   0.140539    0.150865  -0.235660
# rightHip     1.000000  0.623193   0.826482   0.040333    0.141338   0.048222
# leftKnee     0.623193  1.000000   0.605841   0.262692    0.121019  -0.155296
# rightKnee    0.826482  0.605841   1.000000  -0.011907   -0.049040  -0.093236
# leftAnkle    0.040333  0.262692  -0.011907   1.000000    0.145185   0.202865
# rightAnkle   0.141338  0.121019  -0.049040   0.145185    1.000000  -0.006345
# leftWrist    0.048222 -0.155296  -0.093236   0.202865   -0.006345   1.000000
# rightWrist  -0.251859 -0.227607  -0.307560   0.311563    0.240666   0.047147
# Xfactor      0.134391  0.270029  -0.168957   0.234185    0.146511  -0.141909
#
#              rightWrist   Xfactor
# leftElbow     -0.019926  0.003277
# rightElbow    -0.267626 -0.361947
# leftShould     0.213786  0.446321
# rightShould    0.079658  0.430423
# leftHip       -0.114126  0.521714
# rightHip      -0.251859  0.134391
# leftKnee      -0.227607  0.270029
# rightKnee     -0.307560 -0.168957
# leftAnkle      0.311563  0.234185
# rightAnkle     0.240666  0.146511
# leftWrist      0.047147 -0.141909
# rightWrist     1.000000 -0.057897
# Xfactor       -0.057897  1.000000

# %%
sns.heatmap(df_1.corr(), annot=True, fmt=".1f",cmap="Pastel1" )
# Out:
# <Axes: >

# %%
sns.heatmap(df_2.corr(), annot=True, fmt=".1f",cmap="Pastel1" )
# Out:
# <Axes: >

# %%
df_1.corr()[['Xfactor']].sort_values(by='Xfactor', ascending=False)
# Out:
#               Xfactor
# Xfactor      1.000000
# leftHip      0.521714
# leftShould   0.446321
# rightShould  0.430423
# leftKnee     0.270029
# leftAnkle    0.234185
# rightAnkle   0.146511
# rightHip     0.134391
# leftElbow    0.003277
# rightWrist  -0.057897
# leftWrist   -0.141909
# rightKnee   -0.168957
# rightElbow  -0.361947

# %%
c = df_1.corr()
np.fill_diagonal(c.values, 0)
s = c.unstack()
s.sort_values(kind="quicksort")
# Out:
# rightElbow   leftShould    -0.708565
# leftShould   rightElbow    -0.708565
# rightElbow   rightShould   -0.572994
# rightShould  rightElbow    -0.572994
# leftShould   leftWrist     -0.540251
#                               ...
# leftKnee     rightHip       0.623193
# rightKnee    rightHip       0.826482
# rightHip     rightKnee      0.826482
# leftHip      leftKnee       0.841408
# leftKnee     leftHip        0.841408
# Length: 169, dtype: float64

# %%
# Create correlation matrix
corr_mat = df_1.corr(method='pearson')
np.fill_diagonal(corr_mat.values, 0)
# Convert correlation matrix to 1-D Series and sort
sorted_mat = corr_mat.unstack().sort_values(ascending=False)

print(sorted_mat)
s =sorted_mat.abs()
s[s>0.7]
# Out:
# leftHip      leftKnee       0.841408
# leftKnee     leftHip        0.841408
# rightKnee    rightHip       0.826482
# rightHip     rightKnee      0.826482
#              leftKnee       0.623193
#                               ...
# leftWrist    leftShould    -0.540251
# rightElbow   rightShould   -0.572994
# rightShould  rightElbow    -0.572994
# leftShould   rightElbow    -0.708565
# rightElbow   leftShould    -0.708565
# Length: 169, dtype: float64
# leftHip     leftKnee      0.841408
# leftKnee    leftHip       0.841408
# rightKnee   rightHip      0.826482
# rightHip    rightKnee     0.826482
# leftShould  rightElbow    0.708565
# rightElbow  leftShould    0.708565
# dtype: float64

# %%
c = df_2.corr()
np.fill_diagonal(c.values, 0)
s = c.unstack()
s.sort_values(kind="quicksort")
# Out:
# leftKnee    leftWrist    -0.442545
# leftWrist   leftKnee     -0.442545
# rightWrist  leftShould   -0.424781
# leftShould  rightWrist   -0.424781
# rightAnkle  rightElbow   -0.384234
#                             ...
# leftKnee    leftAnkle     0.535663
# leftHip     rightKnee     0.544695
# rightKnee   leftHip       0.544695
# rightHip    rightKnee     0.652342
# rightKnee   rightHip      0.652342
# Length: 169, dtype: float64

# %%
# Create correlation matrix
corr_mat = df_2.corr(method='pearson')
np.fill_diagonal(corr_mat.values, 0)
# Convert correlation matrix to 1-D Series and sort
sorted_mat = corr_mat.unstack().sort_values(ascending=False)

print(sorted_mat)
s =sorted_mat.abs()
s[s>0.5]
# Out:
# rightHip    rightKnee     0.652342
# rightKnee   rightHip      0.652342
#             leftHip       0.544695
# leftHip     rightKnee     0.544695
# leftKnee    leftAnkle     0.535663
#                             ...
# rightElbow  rightAnkle   -0.384234
# leftShould  rightWrist   -0.424781
# rightWrist  leftShould   -0.424781
# leftKnee    leftWrist    -0.442545
# leftWrist   leftKnee     -0.442545
# Length: 169, dtype: float64
# rightHip   rightKnee    0.652342
# rightKnee  rightHip     0.652342
#            leftHip      0.544695
# leftHip    rightKnee    0.544695
# leftKnee   leftAnkle    0.535663
# leftAnkle  leftKnee     0.535663
# dtype: float64

# %%
# Create correlation matrix
corr_mat = df_1.corr(method='pearson')

# Retain upper triangular values of correlation matrix and
# make Lower triangular values Null
upper_corr_mat = corr_mat.where(
    np.triu(np.ones(corr_mat.shape), k=1).astype(bool))

# Convert to 1-D series and drop Null values
unique_corr_pairs = upper_corr_mat.unstack().dropna()

# Sort correlation pairs
sorted_mat = unique_corr_pairs.sort_values()
print(sorted_mat.sort_values(ascending=False))
# Out:
# leftKnee     leftHip       0.841408
# rightKnee    rightHip      0.826482
# leftKnee     rightHip      0.623193
# rightKnee    leftKnee      0.605841
# rightShould  leftShould    0.565548
#                              ...
# rightKnee    leftShould   -0.355641
# Xfactor      rightElbow   -0.361947
# leftWrist    leftShould   -0.540251
# rightShould  rightElbow   -0.572994
# leftShould   rightElbow   -0.708565
# Length: 78, dtype: float64

# %% [markdown]
# ## визуализация

# %%
df_should.plot(figsize=(18,7))
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_should, x="3D_Правое плечо", y="3D_Левое плечо")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='3D_Левое плечо'>

# %%
sns.lineplot(data=df_should, x="3D_Правое плечо", y="3D_Левое плечо")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='3D_Левое плечо'>

# %%
sns.lineplot(data=df_should, x="3D_Правое плечо", y="X-angle")
# Out:
# <Axes: xlabel='3D_Правое плечо', ylabel='X-angle'>

# %%
plt.subplot(1, 2, 1)
sns.countplot(x='3D_Правое плечо', data=df_should)
plt.subplot(1, 2, 2)
sns.countplot(x='3D_Левое плечо', data=df_should)
# Out:
# <Axes: xlabel='3D_Левое плечо', ylabel='count'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df_3['X-angle']
y = df_3['3D_Правое плечо']
z = df_3['3D_Левое плечо']

ax.set_xlabel("X-angle")
ax.set_ylabel('3D_Правое плечо')
ax.set_zlabel('3D_Левое плечо')

ax.scatter(x, y, z)

plt.show()

# %%
#sns.pairplot(df_3, hue="X-angle")

# %% [markdown]
# # Статистика

# %%
df_1.columns
# Out:
# Index(['leftElbow', 'rightElbow', 'leftShould', 'rightShould', 'leftHip',
#        'rightHip', 'leftKnee', 'rightKnee', 'leftAnkle', 'rightAnkle',
#        'leftWrist', 'rightWrist', 'Xfactor'],
#       dtype='object')

# %%
# Mann-Whitney U test

from scipy.stats import mannwhitneyu

stat, p = mannwhitneyu(df_2['Xfactor'], df_1['Xfactor'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=2675.000, p=0.811
# Same distribution (fail to reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal


# compare samples
stat, p = kruskal(df_2['Xfactor'], df_1['Xfactor'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=0.058, p=0.809
# Same distributions (fail to reject H0)

# %% [markdown]
# # Furie

# %%
from scipy.fft import fft, fftfreq,ifft

# %%
df_1['Xfactor'].shift(1) - df_1['Xfactor']
# Out:
# 0          NaN
# 1     0.087843
# 2    -2.140316
# 3    -0.192124
# 4     0.883506
#         ...
# 69   -1.263501
# 70   -0.791188
# 71    0.356981
# 72   -0.749244
# 73    1.570591
# Name: Xfactor, Length: 74, dtype: float64

# %%
(df_1['Xfactor'].shift(1) - df_1['Xfactor']).plot(kind='line')
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt



# Создаем массив значений x от -10 до 10
#x = np.linspace(0, 1843, 1843)
x = range(74)

# Вычисляем значения y для первой и второй функций
y1 = df_1['Xfactor'].shift(1) - df_1['Xfactor']
y2 = df_1['Xfactor']

# Строим график двух функций
plt.plot(x, y1.abs(), label='der')
plt.plot(x, y2, label='raw')

# Добавляем заголовок и метки осей
plt.title('Графики ')
plt.xlabel('x')
plt.ylabel('y')

# Добавляем легенду
plt.legend()

# Показываем график
plt.show()

# %%
from scipy.fft import fft, fftfreq,ifft
fft(df_1['Xfactor'])
# Out:
# array([ 581.8144082   -0.j        , -106.07154859+120.16188522j,
#         -25.44246038 +38.13380953j,  -27.14777573-101.06525608j,
#          51.62697775 +74.6096856j ,  -45.40072368 -43.76790723j,
#           7.28113536 +43.10226535j,   18.82801098 -25.02560579j,
#         -46.06100959 +16.48278264j,   21.87313595 +36.25684664j,
#         -13.94958231  +7.66339156j,  -15.42960145  -7.30478554j,
#          13.00352265  -2.47132858j,    1.07787738 +16.77016792j,
#         -39.88134995 -31.16373606j,   25.44988272 +40.69700649j,
#          -7.41075187 -37.97618788j,  -18.47849862 +22.09009657j,
#           8.7888838  -18.49721112j,   -4.37596525 +27.31555805j,
#          -1.6518279  -18.58402364j,  -29.44977182 +33.69804599j,
#          33.49056879 -19.86712045j,  -36.30352479 +27.80698022j,
#          12.92424881 -16.70405401j,    2.01674553 +23.83155282j,
#          -3.13288517 -31.80204035j,   -4.61209412 +17.97148751j,
#          17.82582291  -0.60237514j,  -29.29180726 -21.33247794j,
#          28.00562541 +23.75333469j,  -13.49154512  -0.93000645j,
#          -9.17647147 -11.69797763j,    9.12413805  +6.51330699j,
#          -5.38282964  +0.22725774j,    5.56281711  -9.99505717j,
#          -6.33005446 +10.39044307j,   10.60002274  -0.j        ,
#          -6.33005446 -10.39044307j,    5.56281711  +9.99505717j,
#          -5.38282964  -0.22725774j,    9.12413805  -6.51330699j,
#          -9.17647147 +11.69797763j,  -13.49154512  +0.93000645j,
#          28.00562541 -23.75333469j,  -29.29180726 +21.33247794j,
#          17.82582291  +0.60237514j,   -4.61209412 -17.97148751j,
#          -3.13288517 +31.80204035j,    2.01674553 -23.83155282j,
#          12.92424881 +16.70405401j,  -36.30352479 -27.80698022j,
#          33.49056879 +19.86712045j,  -29.44977182 -33.69804599j,
#          -1.6518279  +18.58402364j,   -4.37596525 -27.31555805j,
#           8.7888838  +18.49721112j,  -18.47849862 -22.09009657j,
#          -7.41075187 +37.97618788j,   25.44988272 -40.69700649j,
#         -39.88134995 +31.16373606j,    1.07787738 -16.77016792j,
#          13.00352265  +2.47132858j,  -15.42960145  +7.30478554j,
#         -13.94958231  -7.66339156j,   21.87313595 -36.25684664j,
#         -46.06100959 -16.48278264j,   18.82801098 +25.02560579j,
#           7.28113536 -43.10226535j,  -45.40072368 +43.76790723j,
#          51.62697775 -74.6096856j ,  -27.14777573+101.06525608j,
#         -25.44246038 -38.13380953j, -106.07154859-120.16188522j])

# %%
ifft(fft(df_1['Xfactor']))
# Out:
# array([ 1.74633864+0.00000000e+00j,  1.65849572-6.36127787e-16j,
#         3.79881184+0.00000000e+00j,  3.99093605-4.36267336e-16j,
#         3.10743001+0.00000000e+00j,  4.45328144-4.50355588e-16j,
#         6.25407337+0.00000000e+00j,  4.53140884-2.19234768e-16j,
#         3.72144225+0.00000000e+00j,  3.94525704-1.37814490e-16j,
#         2.77550258+0.00000000e+00j,  2.5715105 +5.29532162e-17j,
#         4.03131604+0.00000000e+00j,  4.56573836+5.49859688e-17j,
#         5.52361549+0.00000000e+00j,  4.95067793+8.78328393e-17j,
#         3.28668521+0.00000000e+00j,  2.49038369+1.80153550e-16j,
#         2.71281034+0.00000000e+00j,  3.77499867+6.53851691e-17j,
#         4.59715634+0.00000000e+00j,  4.3917194 -2.54381726e-16j,
#         4.84452743+0.00000000e+00j,  7.29823402-7.47076050e-16j,
#        15.04532531+0.00000000e+00j,  2.22555123-6.91478847e-16j,
#         0.85318011+0.00000000e+00j,  2.98895747-2.45346045e-16j,
#         1.63700735+0.00000000e+00j,  9.8184882 -1.23651604e-16j,
#        10.79573452+0.00000000e+00j, 11.17270464+1.52287193e-16j,
#        15.66181368+0.00000000e+00j, 16.67775869+3.62393682e-16j,
#        29.71644455+0.00000000e+00j, 15.27283615+2.70795651e-16j,
#         2.81095914+0.00000000e+00j, 14.76364876+2.80834964e-16j,
#        15.85129437+0.00000000e+00j,  4.90677783+5.35890228e-16j,
#         5.66433491+0.00000000e+00j,  5.40585431+6.58532290e-16j,
#         4.17731946+0.00000000e+00j,  4.27058305+2.03917140e-16j,
#        10.55348229+0.00000000e+00j,  3.46041998+2.17111326e-16j,
#         2.84179512+0.00000000e+00j, 11.41752998-4.01454660e-17j,
#         7.55398018+0.00000000e+00j, 17.76120902-4.71202747e-16j,
#        16.6046359 +0.00000000e+00j, 14.32916477+2.50324166e-18j,
#        13.14982676+0.00000000e+00j, 13.14439268+2.80910012e-16j,
#        17.9898301 +0.00000000e+00j, 15.85204671+3.03217738e-16j,
#        15.04060096+0.00000000e+00j, 14.20377421+3.45119656e-16j,
#        11.66773133+0.00000000e+00j, 10.80387512+2.81772162e-16j,
#         9.26300781+0.00000000e+00j, 10.42588756+3.34906818e-16j,
#         9.73537125+0.00000000e+00j,  9.35698959+3.77293518e-16j,
#         8.1582465 +0.00000000e+00j,  7.03845285+3.88173661e-16j,
#         7.31726719+0.00000000e+00j,  4.63340191+2.62015295e-16j,
#         4.40555832+0.00000000e+00j,  5.66905909-4.04416720e-17j,
#         6.46024747+0.00000000e+00j,  6.10326688-3.78365965e-16j,
#         6.85251136+0.00000000e+00j,  5.28192039-8.27095227e-16j])

# %%
fftfreq(74,df_1['Xfactor'])
# Out:
# 0     0.000000
# 1     0.008148
# 2     0.007115
# 3     0.010158
# 4     0.017395
#         ...
# 69   -0.011919
# 70   -0.008367
# 71   -0.006642
# 72   -0.003944
# 73   -0.002558
# Name: Xfactor, Length: 74, dtype: float64

# %%
fftfreq(74,df_1['Xfactor']).plot()
# Out:
# <Axes: >

# %%
fftfreq(74,df_2['Xfactor']).plot()
# Out:
# <Axes: >
